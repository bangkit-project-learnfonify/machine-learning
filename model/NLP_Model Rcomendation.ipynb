# %%
# !pip install scikit-learn seaborn
# !pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: googletrans==4.0.0-rc1 in /usr/local/lib/python3.10/dist-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2023.11.17)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2023.1.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.0)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)

# %% [markdown]
# ### Declaration of Library

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv
from tensorflow.keras.models import save_model
from googletrans import Translator
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ### Upload Dataset

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# path_to_course = '/content/drive/My Drive/Bangkit/courses.csv'

# %%
import json
import requests

base_url = 'https://cloud-computing-chi.vercel.app/ml/'

# Replace path with URL
url_to_course = base_url + 'courses'
# url_to_user = base_url + 'users'
# url_to_rating = base_url + 'user-rating'

# %% [markdown]
# ## Reading JSON from URL and Converting to DataFrame with Pandas

# %%
# Reading JSON from URL
response = requests.get(url_to_course)
json_data = response.json()

# Convert JSON to DataFrame
courses = pd.json_normalize(json_data, 'data')
courses.head()
# Out:
#    id                        created_at  \
# 0   1  2023-12-16T16:47:23.175286+00:00
# 1   2  2023-12-16T16:47:23.175286+00:00
# 2   3  2023-12-16T16:47:23.175286+00:00
# 3   4  2023-12-16T16:47:23.175286+00:00
# 4   5  2023-12-16T16:47:23.175286+00:00
#
#                                                title  \
# 0  ¡Luces, celular y acción!Crea contenidosaudiov...
# 1                                 3D CAD Fundamental
# 2                  A Fun Collage - with 30+ Examples
# 3   A travel by SpanishAmerica: Spanish forbeginners
# 4                       Academic and BusinessWriting
#
#                                                 link  \
# 0  https://www.edx.org/learn/marketing/pontificia...
# 1  https://www.coursera.org/learn/3d-cad-fundamental
# 2     https://www.udemy.com/course/5-minute-collage/
# 3  https://www.edx.org/learn/spanish/universidad-...
# 4  https://www.edx.org/learn/writing/university-o...
#
#                             organizer        category   instructor  \
# 0    Pontificia Universidad Javeriana   Communication         None
# 1                            Coursera  Graphic Design          康仕仲
# 2                               Udemy  Graphic Design  Mike Merkur
# 3             Universidad del Rosario        Language         None
# 4  University of California, Berkeley   Communication         None
#
#           level rating     fee  \
# 0  Introductory   None    None
# 1          None    4.7  Gratis
# 2          None    4.0  Gratis
# 3  Introductory   None    None
# 4  Introductory   None    None
#
#                                          description  \
# 0  Smartphone Operation, Value Propositions, Mark...
# 1  There have many three-dimensional shape of the...
# 2  How to Put Together a Photo CollageHow to use ...
# 3                                   Spanish Language
# 4  Diction, Business Writing, Writing, Vocabulary...
#
#                                                image
# 0  https://prod-discovery.edx-cdn.org/media/cours...
# 1  https://d3njjcbhbojbot.cloudfront.net/api/util...
# 2  https://img-b.udemycdn.com/course/240x135/3569...
# 3  https://prod-discovery.edx-cdn.org/media/cours...
# 4  https://prod-discovery.edx-cdn.org/media/cours...

# %% [markdown]
# ## Load Universal Sentence Encoder and Obtain Embeddings

# %%
# Define the URL of the Universal Sentence Encoder module
universal_sentence_encoder_url = "https://tfhub.dev/google/universal-sentence-encoder/4"

# Load the Universal Sentence Encoder model
use_model = hub.load(universal_sentence_encoder_url)
print("Universal Sentence Encoder loaded from %s" % universal_sentence_encoder_url)

# Define a function to obtain embeddings representation from the model
def get_embeddings(input_text):

    return use_model(input_text)
# Out:
# Universal Sentence Encoder loaded from https://tfhub.dev/google/universal-sentence-encoder/4

# %% [markdown]
# ## Fetching and Displaying Course Titles from a JSON API

# %%
url_to_course = base_url + 'courses'

# Fetch JSON content from the URL
response = requests.get(url_to_course)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Normalize JSON data and create a DataFrame
    courses = pd.json_normalize(response.json(), 'data')

    # Assuming the data is a DataFrame with a 'course_title' column
    course_title = courses['title'].tolist()

    # Display the extracted course_title
    print(course_title)
else:
    print(f"Failed to fetch the content. Status code: {response.status_code}")
# Out:
# ['¡Luces, celular y acción!Crea contenidosaudiovisuales de impacto', '3D CAD Fundamental', 'A Fun Collage - with 30+ Examples', 'A travel by SpanishAmerica: Spanish forbeginners', 'Academic and BusinessWriting', 'Academic English: How toWrite an Essay', 'Administración pública yfiscal: cómo se gestionaun gobierno', 'Adobe Illustrator-CC Logo & Graphic Design Crash Course', 'Adobe Photoshop Introduction', 'Adobe Photoshop: Brush Tools', 'Adobe Photoshop: Color Gradient', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Designing Instastories', 'Adobe Photoshop: Digital Imaging Photo Manipulation', 'Adobe Photoshop: Digital Imaging Photo Retouching', 'Adobe Photoshop: Digital Imaging Poster Ads', 'Adobe Photoshop: Digital Imaging Product Showcase', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Layer Mask & Layer Style', 'Adobe Photoshop: Layer System', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Type Tools', 'AI & ChatGPT Prompt for  Digital Marketing, Sales & Growth', 'Algoritmos yProgramación en R', 'All About Dictionary Python', 'Amazing Graphic Design for Beginners in 3 EASY STEPS', 'Analisis Bisnis untuk Pemula : Metode Statistik', 'Arabic for non-ArabicSpeakers', 'Assessing Marketing Materials', 'Balance of Payments andInternational InvestmentPosition Statistics', 'Basic Digital Marketing untuk Pemula', 'Basic of Data Visualization', 'Basic Spanish 1: GettingStarted', 'Basic Spanish 2: One StepFurther', 'Basic Spanish 3: Gettingthere', 'Basic SQL', 'Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Becoming a SuccessfulLeader (InclusiveLeadership Training)', 'Becoming an EffectiveLeader', 'Beginners Guide To Graphic Design Without Paid Software', 'Behavioral Economics andPublic Policy', 'Belajar Excel: Analisis Data', 'Brand & Creative Strategy', 'Brand Campaign Touchpoints', 'Brand Guideline Design', 'Brand Identity Design', 'Brand Positioning Introduction', 'Branding Introduction', 'Building stakeholder value', 'Cohort and Retention Analysis Practice', 'Colours', 'Business Analytics with Excel: Elementary to Advanced', 'Business Communication', 'Business Communications- The Basics', 'Business Metrics', 'Business WritingTechniques', 'Campaign & Media Planning', 'Campaign Fundamentals', 'Campaign Monitoring & Optimization', 'Canva Pro Graphic Design Course for Business Professionals', 'Case Study: Implementing SQL', 'ChatGPT for Data Analysis', 'Climate Change: FinancialRisks and Opportunities', 'Clustering Analysis', 'Cohort and Retention Analysis', 'Complete Introduction into Digital Marketing for Beginners', 'Comunicación efectivapara el líder actual', 'Comunicación yRedacción Digital', 'Concepts of Digital Marketing: Beginner to Pro in 2 hrs-2023', 'Consumer & Audience Insight', 'Content Marketing', 'Correlation Analysis', 'Correlation Analysis', 'Creating Campaign Planning', 'Creating Integrated Marketing Plan', 'Creative Brief', 'Creative Brief and Briefing Process', 'Creativity and Creative Block', 'Critical Thinking &Problem Solving', 'Data Communication', 'Dasar-Dasar Ilmu Data: Penggalian Data', 'Dasar-Dasar Keuangan', 'Dasar-Dasar Pemasaran Digital', 'Dasar-Dasar Pemasaran Media Sosial', 'Data Analysis Fundamental', 'Data Analysis with Excel and Power BI', 'Data Analytics for Lean Six Sigma', 'Logo Design', 'Data Preparation in Database', 'Data Science Introduction', 'Data Science Projects - Data Analysis & Machine Learning', 'Data Science, Machine Learning, Data Analysis, Python & R', 'Data Structure in Python', 'Data Visualization', 'Data Visualization Bokeh', 'Data Visualization Matplotlib', 'Data Visualization Plotly', 'Data Visualization Practice', 'Data Visualization Seaborn', 'Data Visualization Type', 'Database Introduction', 'Dataframe ...

# %%
# Function to translate titles to English
def translate_to_english(text):
    translator = Translator()
    translation = translator.translate(text, dest='en')
    return translation.text

# List to store translated titles
tittle_eng = []

# Translate each title and store in tittle_eng
for judul in course_title:
    translation = translate_to_english(judul)
    tittle_eng.append(translation)

# Display the translated titles
print(tittle_eng)
# Out:
# ['Lights, cell phone and action! Create audiovisual impact content', '3D CAD Fundamental', 'A Fun Collage - with 30+ Examples', 'A travel by Spanish American: Spanish for beginners', 'Academic and Business Writing', 'Academic English: How to Write an Essay', 'Public and Fiscal Administration: How to manage a government', 'Adobe Illustrator-CC Logo & Graphic Design Crash Course', 'Adobe Photoshop Introduction', 'Adobe Photoshop: Brush Tools', 'Adobe Photoshop: Color Gradient', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Designing Instastories', 'Adobe Photoshop: Digital Imaging Photo Manipulation', 'Adobe Photoshop: Digital Imaging Photo Retouching', 'Adobe Photoshop: Digital Imaging Poster Ads', 'Adobe Photoshop: Digital Imaging Product Showcase', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Layer Mask and Layer Style', 'Adobe Photoshop: Layer System', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Type Tools', 'AI & ChatGPT Prompt for  Digital Marketing, Sales & Growth', 'Algorithms and Programming in R', 'All About Dictionary Python', 'Amazing Graphic Design for Beginners in 3 EASY STEPS', 'Business analysis for beginners: statistical methods', 'Arabic for non-Arabic Speakers', 'Assessing Marketing Materials', 'Balance of Payments and International Investment Position Statistics', 'Basic Digital Marketing for Beginners', 'Basic of Data Visualization', 'Basic Spanish 1: GettingStarted', 'Basic Spanish 2: One Step Further', 'Basic Spanish 3: Gettingthere', 'Basic SQL', 'Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Becoming a SuccessfulLeader (InclusiveLeadership Training)', 'Becoming an Effective Leader', 'Beginners Guide To Graphic Design Without Paid Software', 'Behavioral Economics and Public Policy', 'Learning Excel: Data Analysis', 'Brand & Creative Strategy', 'Brand Campaign Touchpoints', 'Brand Guideline Design', 'Brand Identity Design', 'Brand Positioning Introduction', 'Branding Introduction', 'Building stakeholder value', 'Cohort and Retention Analysis Practice', 'Colours', 'Business Analytics with Excel: Elementary to Advanced', 'Business Communication', 'Business Communications- The Basics', 'Business Metrics', 'Business Writing Techniques', 'Campaign & Media Planning', 'Campaign Fundamentals', 'Campaign Monitoring & Optimization', 'Canva Pro Graphic Design Course for Business Professionals', 'Case Study: Implementing SQL', 'ChatGPT for Data Analysis', 'Climate Change: Financial Risks and Opportunities', 'Clustering Analysis', 'Cohort and Retention Analysis', 'Complete Introduction into Digital Marketing for Beginners', 'Effective communication for the current leader', 'Communication and Digital Writing', 'Concepts of Digital Marketing: Beginner to Pro in 2 hrs-2023', 'Consumer and Audience Insight', 'Content Marketing', 'Correlation Analysis', 'Correlation Analysis', 'Creating Campaign Planning', 'Creating Integrated Marketing Plan', 'Creative Brief', 'Creative Brief and Briefing Process', 'Creativity and Creative Block', 'Critical Thinking & Problem Solving', 'Data Communication', 'Fundamentals of Data Science: Data excavation', 'Financial basics', 'Basics of Digital Marketing', 'Basics of Social Media Marketing', 'Data Analysis Fundamental', 'Data Analysis with Excel and Power BI', 'Data Analytics for Lean Six Sigma', 'Logo Design', 'Data Preparation in Database', 'Data Science Introduction', 'Data Science Projects - Data Analysis & Machine Learning', 'Data Science, Machine Learning, Data Analysis, Python & R', 'Data Structure in Python', 'Data Visualization', 'Data Visualization Bokeh', 'Data Visualization Matplotlib', 'Data Visualization Plotly', 'Data Visualization Practice', 'Data Visualization Seaborn', 'Data Visualization Type', ' ...

# %%
# Combine course_title and tittle_eng into a list of tuples
data = list(zip(course_title, tittle_eng))

# Specify the CSV file path
csv_file_path = 'course_title.csv'

# Write data to the CSV file
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['judul kursus', 'judul kursus eng'])

    # Write the data rows
    writer.writerows(data)

# Display a message indicating the CSV file creation
print(f"CSV file '{csv_file_path}' has been created.")
# Out:
# CSV file 'course_title.csv' has been created.

# %%
# Obtain embeddings for tittle_eng
judul_embeddings = use_model(tittle_eng) # memperoleh embedding dari judul yang sudah di traslate

# Convert the list of arrays to a numpy array
judul_embeddings = np.array(judul_embeddings) # konversi list array menjadi array Numpy

# %% [markdown]
# ## Calculate Top Similarities for Translated Title Embeddings

# %%
# List to store indices of top similarities for each title
top_similarities_indices = [] # List ini bertujuan untuk menyimpan indeks dari judul-judul yang memiliki kemiripan kosinus tertinggi dengan setiap judul tertentu.

# Iterate through each title embedding
for i, embedding in enumerate(judul_embeddings):
    # Calculate cosine similarities with all other title embeddings
    similarities = cosine_similarity(embedding.reshape(1, -1), judul_embeddings).flatten()

    # Get indices of top similar titles (excluding self-similarity)
    top_indices = np.argsort(similarities)[-6:-1][::-1]

    # Append the top indices to the list
    top_similarities_indices.append(top_indices)

# %%
# Iterate through the indices of top similarities for each title
for n, similar in enumerate(top_similarities_indices):
    judul_similar = []

    # Retrieve titles corresponding to the top similar indices
    for index in similar:
        judul_similar.append(course_title[index])

    # Display the original title and its top similar titles
    print(f"{course_title[n]}:\n {judul_similar}")
    print()
# Out:
# ¡Luces, celular y acción!Crea contenidosaudiovisuales de impacto:
#  ['Merancang dan Mengkreasikan Iklan Dengan Semiotika Visual', 'Graphic Elements of Design: Color Theory and Image Formats', 'Foundations of Digital Marketing and E-commerce', 'Introduction and Installation', 'Comunicación yRedacción Digital']
#
# 3D CAD Fundamental:
#  ['Fundamentals of Graphic Design', 'Data Analysis Fundamental', 'Foundations of Finance', 'Interactive Computer Graphics', 'Basic SQL']
#
# A Fun Collage - with 30+ Examples:
#  ['Learn Canva & Canva Pro - Easiest Graphic Design Course 2023', 'Amazing Graphic Design for Beginners in 3 EASY STEPS', 'Inspiration: Success & Award Winning Campaigns', 'Leading High-PerformingTeams', 'The Ultimate Canva Course For Beginners: Graphic Design']
#
# A travel by SpanishAmerica: Spanish forbeginners:
#  ['Basic Spanish 1: GettingStarted', 'Basic Spanish 2: One StepFurther', 'Basic Spanish 3: Gettingthere', 'Francés Introductorio', 'Pengantar Analisis Merek Digital untuk Pemula']
#
# Academic and BusinessWriting:
#  ['Business WritingTechniques', 'Comunicación yRedacción Digital', 'Leer y escribir en launiversidad', 'Academic English: How toWrite an Essay', 'Upper-IntermediateEnglish: Business andIndustry']
#
# Academic English: How toWrite an Essay:
#  ['Academic and BusinessWriting', 'IELTS Academic TestPreparation', 'Leer y escribir en launiversidad', 'Understanding the TOEFLEssentials Test', 'Inglés para todos: nivelbásico']
#
# Administración pública yfiscal: cómo se gestionaun gobierno:
#  ['Behavioral Economics andPublic Policy', 'Public Speaking', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Becoming an EffectiveLeader', 'Introduction toMathematics for Financeand Business']
#
# Adobe Illustrator-CC Logo & Graphic Design Crash Course:
#  ["Vectr: Beginner's Guide To Graphic Design", 'Beginners Guide To Graphic Design Without Paid Software', 'Graphic Design Theory for beginners', 'Adobe Photoshop: Designing Instastories', 'Introduction To Graphic Design']
#
# Adobe Photoshop Introduction:
#  ['Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Designing Instastories', 'Adobe Photoshop: Layer System', 'Adobe Photoshop: Coloring']
#
# Adobe Photoshop: Brush Tools:
#  ['Adobe Photoshop: Type Tools', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Layer System']
#
# Adobe Photoshop: Color Gradient:
#  ['Adobe Photoshop: Coloring', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Designing Instastories', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Selection']
#
# Adobe Photoshop: Coloring:
#  ['Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Color Gradient', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Designing Instastories']
#
# Adobe Photoshop: Designing Instastories:
#  ['Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Layer System', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Color Gradient']
#
# Adobe Photoshop: Digital Imaging Photo Manipulation:
#  ['Adobe Photoshop: Digital Imaging Photo Retouching', 'Adobe Photoshop: Digital Imaging Product Showcase', 'Adobe Photoshop: Digital Imaging Poster Ads', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Designing Instastories']
#
# Adobe Photoshop: Digital Imaging Photo Retouching:
#  ['Adobe Photoshop: Digital Imaging Photo Manipulation', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Digital Imaging Product Showcase', 'Adobe Photoshop: Digital Imaging Poster Ads', 'Adobe Photoshop: Coloring']
#
# Adobe Photoshop: Digital Imaging Poster Ads:
#  ['Adobe Photoshop: Digital Imaging Product Showcase', 'Adobe Photoshop: Digital Imaging Photo Manipulation', 'Adobe Photoshop: Digital Imaging Photo Retouching', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Designing Instastories']
#
# Adobe Photoshop: Digital Imaging Product Showcase:
#  ['Adobe Photoshop: Digital Imaging Photo Manipulation', 'Adobe Photoshop: Digital Imaging Poster Ads', 'Adobe Photoshop: Digital Imaging Photo Retouching', 'Adobe Photoshop: Designing Instastories', 'Adobe Photoshop: Product Photo Retouching']
#
# Adobe Photoshop: Duotone Effect:
#  ['Adobe Photoshop: Coloring', 'Adobe Photoshop: Designing Instastories', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Layer System', 'Adobe Photoshop: Product Photo Retouching']
#
# Adobe Photoshop: Layer Mask & Layer Style:
#  ['Adobe Photoshop: Layer System', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Designing Instastories', 'Adobe Photoshop: Brush Tools']
#
# Adobe Photoshop: Layer System:
#  ['Adobe Photoshop: Selection', 'Adobe Photoshop: Designing Instastories', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Layer Mask & Layer Style', 'Adobe Photoshop: Coloring']
#
# Adobe Photoshop: Product Photo Retouching:
#  ['Adobe Photoshop: Digital Imaging Photo Retouching', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Brush Tools', 'Adobe Photoshop: Selection']
#
# Adobe Photoshop: Selection:
#  ['Adobe Photoshop: Layer System', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Type Tools', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Brush Tools']
#
# Adobe Photoshop: Type Tools:
#  ['Adobe Photoshop: Brush Tools', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Layer System', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Designing Instastories']
#
# AI & ChatGPT Prompt for  Digital Marketing, Sales & Growth:
#  ['Digital Marketing Course | Digital Marketing Tutorial', 'Digital Marketing FAQs - Common Digital Marketing Questions', 'Marketing for Entrepreneurs in 2022: Learn Digital Marketing', 'Strategi Memulai Digital Marketing dari Awal', 'Dasar-Dasar Pemasaran Digital']
#
# Algoritmos yProgramación en R:
#  ['Data Science, Machine Learning, Data Analysis, Python & R', 'Data Science Projects - Data Analysis & Machine Learning', 'UCI Data Preprocessing and Exploratory Data Analysis', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Plotly for Data Analysis & Data Science']
#
# All About Dictionary Python:
#  ['String in Python', 'List Fundamental in Python', 'Data Structure in Python', 'Function in Python', 'Regular Expression Python']
#
# Amazing Graphic Design for Beginners in 3 EASY STEPS:
#  ['The Ultimate Canva Course For Beginners: Graphic Design', "Vectr: Beginner's Guide To Graphic Design", 'Beginners Guide To Graphic Design Without Paid Software', 'Graphic Design Theory for beginners', 'Learn Canva & Canva Pro - Easiest Graphic Design Course 2023']
#
# Analisis Bisnis untuk Pemula : Metode Statistik:
#  ['Metodologi Penelitian untuk Pemula', 'Fundamentals Data Analysis & Decision Making Models - Theory', 'Python and Statistics for Financial Analysis', 'Pengantar Analisis Merek Digital untuk Pemula', 'Basics of Plotly for Data Analysis & Data Science']
#
# Arabic for non-ArabicSpeakers:
#  ['Mandarin Chinese forBusiness', 'Mandarin ChineseEssentials', 'Mandarin Chinese Level 1', 'Italian Language andCulture: Advanced(2023-2024)', 'Basic Spanish 3: Gettingthere']
#
# Assessing Marketing Materials:
#  ['Content Marketing', 'Paid Content Marketing', 'Marketing Business Metrics', 'Marketing Analytics: Experiment & Evaluation', 'Marketing Introduction']
#
# Balance of Payments andInternational InvestmentPosition Statistics:
#  ['Climate Change: FinancialRisks and Opportunities', 'Financial accounting andcapital markets', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Finanzas e inversionespara no financieros', 'Analisis Bisnis untuk Pemula : Metode Statistik']
#
# Basic Digital Marketing untuk Pemula:
#  ['Digital Marketing Course for Beginners', 'Kursus Digital Marketing untuk Pemula', 'Digital Marketing for Beginners 2023', 'Dasar-Dasar Pemasaran Digital', 'Complete Introduction into Digital Marketing for Beginners']
#
# Basic of Data Visualization:
#  ['Data Visualization Plotly', 'Data Visualization', 'Data Visualization Type', 'Data Visualization Practice', 'Data Visualization Seaborn']
#
# Basic Spanish 1: GettingStarted:
#  ['Basic Spanish 3: Gettingthere', 'Basic Spanish 2: One StepFurther', 'A travel by SpanishAmerica: Spanish forbeginners', 'English for Journalists,Part 1', 'Francés Introductorio']
#
# Basic Spanish 2: One StepFurther:
#  ['Basic Spanish 1: GettingStarted', 'Basic Spanish 3: Gettingthere', 'A travel by SpanishAmerica: Spanish forbeginners', 'Inglés para todos: nivelbásico más', 'Inglés para todos: nivelbásico']
#
# Basic Spanish 3: Gettingthere:
#  ['Basic Spanish 1: GettingStarted', 'Basic Spanish 2: One StepFurther', 'A travel by SpanishAmerica: Spanish forbeginners', 'Mandarin ChineseEssentials', 'Basic SQL']
#
# Basic SQL:
#  ['SQL Keyword', 'SQL Joins', 'Database Introduction', 'SQL String and Date Function', 'Case Study: Implementing SQL']
#
# Basics of Matplotlib for Data Analysis & Data Science:
#  ['Basics of Seaborn for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R']
#
# Basics of Numpy for Data Analysis & Data Science:
#  ['Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R']
#
# Basics of Pandas for Data Analysis & Data Science:
#  ['Basics of Seaborn for Data Analysis & Data Science', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R']
#
# Basics of Plotly for Data Analysis & Data Science:
#  ['Basics of Seaborn for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science', 'Data Science Projects - Data Analysis & Machine Learning']
#
# Basics of Seaborn for Data Analysis & Data Science:
#  ['Basics of Plotly for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R']
#
# Becoming a SuccessfulLeader (InclusiveLeadership Training):
#  ['Leading With EffectiveCommunication (InclusiveLeadership Training)', 'Becoming an EffectiveLeader', 'Kursus Digital Marketing untuk Pemula', 'Pelatihan Esensial Power BI', 'Digital Marketing Course for Beginners']
#
# Becoming an EffectiveLeader:
#  ['Comunicación efectivapara el líder actual', 'Becoming a SuccessfulLeader (InclusiveLeadership Training)', 'Leaders of Learning', 'Kepemimpinan Proyek', 'Leading High-PerformingTeams']
#
# Beginners Guide To Graphic Design Without Paid Software:
#  ["Vectr: Beginner's Guide To Graphic Design", 'Graphic Design Basics for Educators Using Free Software', 'Graphic Design Theory for beginners', 'The Ultimate Canva Course For Beginners: Graphic Design', 'Adobe Illustrator-CC Logo & Graphic Design Crash Course']
#
# Behavioral Economics andPublic Policy:
#  ['Monetary Policy Analysisand Forecasting', 'Principios de Economíaaplicados a Negocios', 'Principios de Economía', 'Macroeconomics ofClimate Change: Science,Economics, and Policies', 'Administración pública yfiscal: cómo se gestionaun gobierno']
#
# Belajar Excel: Analisis Data:
#  ['Data Analysis with Excel and Power BI', 'Business Analytics with Excel: Elementary to Advanced', 'ChatGPT for Data Analysis', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science']
#
# Brand & Creative Strategy:
#  ['Brand Identity Design', 'Brand Guideline Design', 'Designing Brand Identity', 'Brand Campaign Touchpoints', 'The Strategy of Content Marketing']
#
# Brand Campaign Touchpoints:
#  ['Brand & Creative Strategy', 'Campaign Fundamentals', 'Branding Introduction', 'Campaign & Media Planning', 'Creating Campaign Planning']
#
# Brand Guideline Design:
#  ['Brand Identity Design', 'Designing Brand Identity', 'Brand Positioning Introduction', 'Brand & Creative Strategy', 'Design Terminology']
#
# Brand Identity Design:
#  ['Designing Brand Identity', 'Brand Guideline Design', 'Branding Introduction', 'Brand & Creative Strategy', 'Logo Design']
#
# Brand Positioning Introduction:
#  ['Branding Introduction', 'Marketing Introduction', 'Brand Guideline Design', 'Brand Identity Design', 'Introduction to Typography']
#
# Branding Introduction:
#  ['Brand Positioning Introduction', 'Marketing Introduction', 'Brand Identity Design', 'Introduction to Typography', 'Introduction To Graphic Design']
#
# Building stakeholder value:
#  ['Assessing Marketing Materials', 'Pelatihan Penting Tableau', 'Creating Campaign Planning', 'Brand & Creative Strategy', 'Creating Integrated Marketing Plan']
#
# Cohort and Retention Analysis Practice:
#  ['Cohort and Retention Analysis', 'Regression and Inferential Analysis', 'Clustering Analysis', 'UCI Data Preprocessing and Exploratory Data Analysis', 'Belajar Excel: Analisis Data']
#
# Colours:
#  ['Typography', 'Graphic Design', 'Descriptive Analysis', 'Design Styles', 'Adobe Photoshop: Coloring']
#
# Business Analytics with Excel: Elementary to Advanced:
#  ['Belajar Excel: Analisis Data', 'Data Analysis with Excel and Power BI', 'From Excel to Power BI', 'Basics of Plotly for Data Analysis & Data Science', 'Data Analytics for Lean Six Sigma']
#
# Business Communication:
#  ['Business Communications- The Basics', 'Data Communication', 'Business Metrics', 'Professional BusinessPresentations', 'Business WritingTechniques']
#
# Business Communications- The Basics:
#  ['Business Communication', 'Data Communication', 'Professional BusinessPresentations', 'Comunicación yRedacción Digital', 'Dasar-Dasar Pemasaran Digital']
#
# Business Metrics:
#  ['Marketing Business Metrics', 'Business Communication', 'Professional BusinessPresentations', 'Statistics', 'Statistics Introduction']
#
# Business WritingTechniques:
#  ['Academic and BusinessWriting', 'Business Communication', 'Writing Feature Articles', 'Upper-IntermediateEnglish: Business andTechnology', 'Professional BusinessPresentations']
#
# Campaign & Media Planning:
#  ['Funnelling & Media Planning', 'Creating Campaign Planning', 'Preparing Your Career as Campaign Planner', 'Campaign Monitoring & Optimization', 'Brand Campaign Touchpoints']
#
# Campaign Fundamentals:
#  ['Media Fundamentals', 'Brand Campaign Touchpoints', 'Creating Campaign Planning', 'Campaign & Media Planning', 'Campaign Monitoring & Optimization']
#
# Campaign Monitoring & Optimization:
#  ['Campaign & Media Planning', 'Creating Campaign Planning', 'Pemasaran Media Sosial: Strategi dan Pengoptimalan', 'Campaign Fundamentals', 'Digital Platforms inPerformance']
#
# Canva Pro Graphic Design Course for Business Professionals:
#  ['Professional Advertising & Graphic Design [Mascot/Logo]', 'Graphic Design Career Opportunity', 'Learn Canva & Canva Pro - Easiest Graphic Design Course 2023', 'The Ultimate Canva Course For Beginners: Graphic Design', 'Beginners Guide To Graphic Design Without Paid Software']
#
# Case Study: Implementing SQL:
#  ['SQL for Data Analysis: Solving real-world problems with data', 'Basic SQL', 'SQL Joins', 'SQL Keyword', 'SQL Mastery & Data Analysis - A Teaser']
#
# ChatGPT for Data Analysis:
#  ['Basics of Plotly for Data Analysis & Data Science', 'Data Analysis Fundamental', 'Visualisasi Data untuk Analisis dan Analitik Data', 'Basics of Seaborn for Data Analysis & Data Science', 'UCI Data Preprocessing and Exploratory Data Analysis']
#
# Climate Change: FinancialRisks and Opportunities:
#  ['Macroeconomics ofClimate Change: ClimateRisks for the Financial Se…', 'Macroeconomics ofClimate Change: Science,Economics, and Policies', 'Macroeconomics ofClimate Change: GreenPublic Finance', 'Inclusive Growth: ClimateChange', 'Monetary Policy Analysisand Forecasting']
#
# Clustering Analysis:
#  ['ChatGPT for Data Analysis', 'Data Analysis Fundamental', 'Correlation Analysis', 'Correlation Analysis', 'Project: Clustering Model']
#
# Cohort and Retention Analysis:
#  ['Cohort and Retention Analysis Practice', 'Regression and Inferential Analysis', 'Clustering Analysis', 'UCI Data Preprocessing and Exploratory Data Analysis', 'ChatGPT for Data Analysis']
#
# Complete Introduction into Digital Marketing for Beginners:
#  ['Basic Digital Marketing untuk Pemula', 'Digital Marketing Course for Beginners', 'Digital Marketing for Beginners 2023', 'Kursus Digital Marketing untuk Pemula', 'Introduction to Digital Marketing']
#
# Comunicación efectivapara el líder actual:
#  ['Becoming an EffectiveLeader', 'Business Communication', 'El poder de lacomunicación consciente', 'Business Communications- The Basics', 'Kepemimpinan Proyek']
#
# Comunicación yRedacción Digital:
#  ['Academic and BusinessWriting', 'Business Communication', 'Business Communications- The Basics', 'Data Communication', 'Foundations of Digital Marketing and E-commerce']
#
# Concepts of Digital Marketing: Beginner to Pro in 2 hrs-2023:
#  ['Basic Digital Marketing untuk Pemula', 'Digital Marketing Course for Beginners', 'Kursus Digital Marketing untuk Pemula', 'Digital Marketing Course | Digital Marketing Tutorial', 'Complete Introduction into Digital Marketing for Beginners']
#
# Consumer & Audience Insight:
#  ['Public Speaking', 'Behavioral Economics andPublic Policy', 'Academic and BusinessWriting', 'Market Research & Objective', 'Pemasaran Media Sosial: Strategi dan Pengoptimalan']
#
# Content Marketing:
#  ['Paid Content Marketing', 'The Strategy of Content Marketing', 'Dasar-Dasar Pemasaran Digital', 'Dasar-Dasar Pemasaran Media Sosial', 'Introduction to Digital Marketing']
#
# Correlation Analysis:
#  ['Correlation Analysis', 'Clustering Analysis', 'Regression and Inferential Analysis', 'Descriptive Analysis', 'Text Analysis']
#
# Correlation Analysis:
#  ['Correlation Analysis', 'Clustering Analysis', 'Regression and Inferential Analysis', 'Descriptive Analysis', 'Text Analysis']
#
# Creating Campaign Planning:
#  ['Campaign & Media Planning', 'Preparing Your Career as Campaign Planner', 'Creating Integrated Marketing Plan', 'Funnelling & Media Planning', 'Campaign Fundamentals']
#
# Creating Integrated Marketing Plan:
#  ['Creating Campaign Planning', 'Marketing Introduction', 'Marketing Business Metrics', 'Strategi Memulai Digital Marketing dari Awal', 'Dasar-Dasar Pemasaran Digital']
#
# Creative Brief:
#  ['Creative Brief and Briefing Process', 'Creativity and Creative Block', 'Design Terminology', 'Business WritingTechniques', 'Marketing Introduction']
#
# Creative Brief and Briefing Process:
#  ['Creative Brief', 'Tips dan Trik Visualisasi Data', 'Creativity and Creative Block', 'Academic and BusinessWriting', 'Introduction to PersonalFinancial Planning']
#
# Creativity and Creative Block:
#  ['Creative Brief', 'How to Ideate: Creative Strategy/Brief', 'Brand & Creative Strategy', 'Creative Brief and Briefing Process', 'Ideas from the History of Graphic Design']
#
# Critical Thinking &Problem Solving:
#  ['SQL for Data Analysis: Solving real-world problems with data', 'Pengantar Analisis Data untuk Memecahkan Masalah Kualitas', 'Hypothesis Testing', 'Data Analysis Fundamental', 'Dasar-Dasar Keuangan']
#
# Data Communication:
#  ['Business Communication', 'Data Visualization', 'Business Communications- The Basics', 'Data Visualization Type', 'Data Analysis Fundamental']
#
# Dasar-Dasar Ilmu Data: Penggalian Data:
#  ['Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Data Science Projects - Data Analysis & Machine Learning', 'Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science']
#
# Dasar-Dasar Keuangan:
#  ['Foundations of Finance', 'Fundamentos deinformación financiera ycontable', 'Información financiera ysu análisis', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Financial Market Analysis']
#
# Dasar-Dasar Pemasaran Digital:
#  ['Digital Marketing Course | Digital Marketing Tutorial', 'Introduction to Digital Marketing', 'Digital Marketing Essentials Masterclass', 'Basic Digital Marketing untuk Pemula', 'Dasar-Dasar Pemasaran Media Sosial']
#
# Dasar-Dasar Pemasaran Media Sosial:
#  ['Social Media Marketing untuk Pemula', 'Dasar-Dasar Pemasaran Digital', 'Media Sosial dan Mobile Marketing', 'Pemasaran: Naskah Iklan untuk Media Sosial', 'Basic Digital Marketing untuk Pemula']
#
# Data Analysis Fundamental:
#  ['ChatGPT for Data Analysis', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Dasar-Dasar Ilmu Data: Penggalian Data', 'Clustering Analysis']
#
# Data Analysis with Excel and Power BI:
#  ['From Excel to Power BI', 'Belajar Excel: Analisis Data', 'Business Analytics with Excel: Elementary to Advanced', 'Visualisasi Data untuk Analisis dan Analitik Data', 'ChatGPT for Data Analysis']
#
# Data Analytics for Lean Six Sigma:
#  ['Basics of Plotly for Data Analysis & Data Science', 'Data Science Projects - Data Analysis & Machine Learning', 'Basics of Seaborn for Data Analysis & Data Science', 'Visualisasi Data untuk Analisis dan Analitik Data', 'UCI Data Preprocessing and Exploratory Data Analysis']
#
# Logo Design:
#  ['Graphic Design', 'Introduction to Graphic Design', 'Introduction To Graphic Design', 'Fundamentals of Graphic Design', 'Graphic Design Resources']
#
# Data Preparation in Database:
#  ['Database Introduction', 'Data Science Introduction', 'Introduction to Data Preprocessing', 'Basic of Data Visualization', 'ChatGPT for Data Analysis']
#
# Data Science Introduction:
#  ['Introduction to Data Preprocessing', 'Basics of Plotly for Data Analysis & Data Science', 'Introduction to Machine Learning', 'Dasar-Dasar Ilmu Data: Penggalian Data', 'Basics of Seaborn for Data Analysis & Data Science']
#
# Data Science Projects - Data Analysis & Machine Learning:
#  ['Data Science, Machine Learning, Data Analysis, Python & R', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science']
#
# Data Science, Machine Learning, Data Analysis, Python & R:
#  ['Data Science Projects - Data Analysis & Machine Learning', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science']
#
# Data Structure in Python:
#  ['Python for Data Analysis', 'String in Python', 'List Fundamental in Python', 'Function in Python', 'Python 101 - For Data Analysis']
#
# Data Visualization:
#  ['Data Visualization Plotly', 'Data Visualization Practice', 'Data Visualization Type', 'Data Visualization Seaborn', 'Basic of Data Visualization']
#
# Data Visualization Bokeh:
#  ['Data Visualization Seaborn', 'Data Visualization Plotly', 'Data Visualization', 'Data Visualization Matplotlib', 'Data Visualization Type']
#
# Data Visualization Matplotlib:
#  ['Data Visualization Seaborn', 'Data Visualization Plotly', 'Data Visualization Bokeh', 'Basics of Matplotlib for Data Analysis & Data Science', 'Data Visualization']
#
# Data Visualization Plotly:
#  ['Data Visualization', 'Data Visualization Seaborn', 'Basic of Data Visualization', 'Data Visualization Type', 'Data Visualization Practice']
#
# Data Visualization Practice:
#  ['Data Visualization', 'Data Visualization Plotly', 'Basic of Data Visualization', 'Data Visualization Type', 'Tips dan Trik Visualisasi Data']
#
# Data Visualization Seaborn:
#  ['Data Visualization Plotly', 'Data Visualization Matplotlib', 'Data Visualization', 'Data Visualization Bokeh', 'Data Visualization Type']
#
# Data Visualization Type:
#  ['Data Visualization Plotly', 'Data Visualization', 'Basic of Data Visualization', 'Data Visualization Seaborn', 'Data Visualization Practice']
#
# Database Introduction:
#  ['Data Preparation in Database', 'Data Science Introduction', 'Introduction to Data Preprocessing', 'Introduction to FinTech', 'Introduction to Statistics']
#
# Dataframe Aggregate:
#  ['Dataframe Merge', 'Basics of Pandas for Data Analysis & Data Science', 'Foundations of Data Science: K-Means Clustering in Python', 'Pandas Datetime', 'SQL Advance: Group By & Agregat']
#
# Dataframe Merge:
#  ['Dataframe Aggregate', 'Pandas Datetime', 'Foundations of Data Science: K-Means Clustering in Python', 'Basics of Pandas for Data Analysis & Data Science', 'Algoritmos yProgramación en R']
#
# Datetime:
#  ['Pandas Datetime', 'SQL String and Date Function', 'MacroeconometricForecasting', 'Relationship and Alter Table', 'String in Python']
#
# Descriptive Analysis:
#  ['Text Analysis', 'Clustering Analysis', 'Data Analysis Fundamental', 'Correlation Analysis', 'Correlation Analysis']
#
# Design Element:
#  ['Design Styles', 'Design Principles', 'Design Terminology', 'Logo Design', 'Brand Identity Design']
#
# Design Principles:
#  ['Design Styles', 'Design Element', 'Design Terminology', 'Principios de Economía', 'Brand Guideline Design']
#
# Design Styles:
#  ['Design Terminology', 'Design Element', 'Design Principles', 'Graphic Design', 'Brand Guideline Design']
#
# Design Terminology:
#  ['Design Styles', 'Brand Guideline Design', 'Design Principles', 'Design Element', 'Fundamentals of Graphic Design']
#
# Designing Brand Identity:
#  ['Brand Identity Design', 'Brand Guideline Design', 'Brand & Creative Strategy', 'Branding Introduction', 'Design Styles']
#
# Digital Marketing Course | Digital Marketing Tutorial:
#  ['Digital Marketing Course for Beginners', 'Kursus Digital Marketing untuk Pemula', 'Dasar-Dasar Pemasaran Digital', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing FAQs - Common Digital Marketing Questions']
#
# Digital Marketing Course for Beginners:
#  ['Kursus Digital Marketing untuk Pemula', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing for Beginners 2023', 'Digital Marketing Course | Digital Marketing Tutorial', 'Complete Introduction into Digital Marketing for Beginners']
#
# Digital Marketing Essentials Masterclass:
#  ['Dasar-Dasar Pemasaran Digital', 'Digital Marketing Course | Digital Marketing Tutorial', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing Course for Beginners', 'Kursus Digital Marketing untuk Pemula']
#
# Digital Marketing FAQs - Common Digital Marketing Questions:
#  ['Digital Marketing Course | Digital Marketing Tutorial', 'Dasar-Dasar Pemasaran Digital', 'Digital Marketing Essentials Masterclass', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing for Beginners 2023']
#
# Digital Marketing for Beginners 2023:
#  ['Digital Marketing Course for Beginners', 'Basic Digital Marketing untuk Pemula', 'Kursus Digital Marketing untuk Pemula', 'Complete Introduction into Digital Marketing for Beginners', 'Digital Marketing Course | Digital Marketing Tutorial']
#
# Digital Marketing for Plumbers | Plumbing Marketing 2023:
#  ['Marketing for Entrepreneurs in 2022: Learn Digital Marketing', 'Digital Marketing Course | Digital Marketing Tutorial', 'Pemasaran: Naskah Iklan untuk Media Sosial', 'Digital Marketing for Beginners 2023', 'Introduction to Digital Marketing']
#
# Digital Marketing Masterclass in 2 Hours:
#  ['Digital Marketing Essentials Masterclass', 'Digital Marketing Course | Digital Marketing Tutorial', 'Digital Marketing for Beginners 2023', 'Dasar-Dasar Pemasaran Digital', 'Digital Marketing Course for Beginners']
#
# Digital Marketing Strategy for Managers:
#  ['Dasar-Dasar Pemasaran Digital', 'Strategi Memulai Digital Marketing dari Awal', 'Digital Marketing Course | Digital Marketing Tutorial', 'Digital Marketing FAQs - Common Digital Marketing Questions', 'Introduction to Digital Marketing']
#
# Digital Marketing Strategy with Goldman Sachs 10,000 Women:
#  ['Digital Marketing Masterclass in 2 Hours', 'Digital Marketing Strategy for Managers', 'Digital Marketing Course | Digital Marketing Tutorial', 'Strategi Memulai Digital Marketing dari Awal', 'Marketing for Entrepreneurs in 2022: Learn Digital Marketing']
#
# Digital Performance Marketing: Tips Memulai Beriklan Online:
#  ['Digital Marketing Course | Digital Marketing Tutorial', 'Strategi Memulai Digital Marketing dari Awal', 'Complete Introduction into Digital Marketing for Beginners', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing Course for Beginners']
#
# Digital Platforms inPerformance:
#  ['Digital Performance Marketing: Tips Memulai Beriklan Online', 'Kursus Digital Marketing untuk Pemula', 'Digital Marketing Course for Beginners', 'Digital Marketing Essentials Masterclass', 'Campaign Monitoring & Optimization']
#
# Economics: ConsumerDemand:
#  ['Feature Extraction', 'Market Research & Objective', 'Principios de Economía', 'Hypothesis Testing', 'Principios de Economíaaplicados a Negocios']
#
# Edición de vídeo ypostproducción conDaVinci Resolve. Básico:
#  ['Interactive Computer Graphics', 'Media Fundamentals', 'Professional Advertising & Graphic Design [Mascot/Logo]', 'Steps in Japanese forBeginners1 Part1', 'Adobe Photoshop: Designing Instastories']
#
# El arte de vender:introducción a las ventas:
#  ['Marketing Introduction', 'Introducción a lasfinanzas: Principios devaloración', 'Introduction to Digital Marketing', 'Complete Introduction into Digital Marketing for Beginners', 'Introducción a la inversiónbursátil']
#
# El cerebro y las emocionesen el lenguaje:
#  ['The Language of Design: Form and Meaning', 'El poder de lacomunicación consciente', 'Italian Language andCulture: Beginner(2023-2024)', 'Italian Language andCulture: Advanced(2023-2024)', 'Italian Language andCulture: Intermediate(2023-2024)']
#
# El poder de lacomunicación consciente:
#  ['Data Communication', 'Business Communication', 'Comunicación efectivapara el líder actual', 'Business Communications- The Basics', 'El cerebro y las emocionesen el lenguaje']
#
# Email marketing: diseño ygestión de campañas:
#  ['Marketing for Entrepreneurs in 2022: Learn Digital Marketing', 'Digital Marketing Course | Digital Marketing Tutorial', 'Digital Marketing Strategy for Managers', 'Strategi Memulai Digital Marketing dari Awal', 'Foundations of Digital Marketing and E-commerce']
#
# English for Journalists,Part 1:
#  ['Inglés para todos: nivelbásico', 'Inglés para todos: nivelbásico más', 'Basic Spanish 1: GettingStarted', 'Mandarin Chinese Level 1', 'Francés Introductorio']
#
# Entrepreneurship Skala Lokal hingga Global:
#  ['Launch Your Online Business', 'Launch Your Online Business', 'Upper-IntermediateEnglish: Business andGlobalization', 'Inspiration: Success & Award Winning Campaigns', 'Strategi Memulai Digital Marketing dari Awal']
#
# Evaluating Impact in Low-and Middle-IncomeCountries:
#  ['Assessing Marketing Materials', 'Building stakeholder value', 'Entrepreneurship Skala Lokal hingga Global', 'Using Email forNetworking in English', 'Introducción a lasfinanzas: Principios devaloración']
#
# Principios de Economíaaplicados a Negocios:
#  ['Principios de Economía', 'Behavioral Economics andPublic Policy', 'Design Principles', 'Analisis Bisnis untuk Pemula : Metode Statistik', 'Macroeconomics ofClimate Change: Science,Economics, and Policies']
#
# Facebook Ads: Cómoutilizar el poder de lapublicidad en Facebook:
#  ['Pemasaran: Naskah Iklan untuk Media Sosial', 'Digital Performance Marketing: Tips Memulai Beriklan Online', 'Social Media Marketing untuk Pemula', 'Digital Marketing FAQs - Common Digital Marketing Questions', 'Pemasaran Media Sosial: Strategi dan Pengoptimalan']
#
# Feature Engineering:
#  ['Feature Extraction', 'Design Element', 'Project: Clustering Model', 'Design Terminology', 'Design Principles']
#
# Feature Extraction:
#  ['Feature Engineering', 'Descriptive Analysis', 'Project: Clustering Model', 'Clustering Analysis', 'Economics:\xa0ConsumerDemand']
#
# Financial accounting andcapital markets:
#  ['Financial Market Analysis', 'Finanzas e inversionespara no financieros', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Fundamentos deinformación financiera ycontable', 'Financial Development andFinancial Inclusion']
#
# Financial Development andFinancial Inclusion:
#  ['Finanzas e inversionespara no financieros', 'Fundamentos deinformación financiera ycontable', 'Dasar-Dasar Keuangan', 'Financial Programmingand Policies, Part 1:Macroeconomic Account…', 'Financial accounting andcapital markets']
#
# Financial Market Analysis:
#  ['Información financiera ysu análisis', 'Financial accounting andcapital markets', 'Data Analysis Fundamental', 'Dasar-Dasar Keuangan', 'Descriptive Analysis']
#
# Financial Programmingand Policies, Part 1:Macroeconomic Account…:
#  ['Financial Development andFinancial Inclusion', 'Financial accounting andcapital markets', 'Finanzas e inversionespara no financieros', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Fundamentos deinformación financiera ycontable']
#
# Finanzas e inversionespara no financieros:
#  ['Financial accounting andcapital markets', 'Financial Development andFinancial Inclusion', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Fundamentos deinformación financiera ycontable', 'Dasar-Dasar Keuangan']
#
# Finding the Brand Benefit:
#  ['Brand Identity Design', 'Designing Brand Identity', 'Brand Positioning Introduction', 'Brand Guideline Design', 'Branding Introduction']
#
# Foundations of Data Science: K-Means Clustering in Python:
#  ['Basics of Numpy for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R', 'Basics of Pandas for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science']
#
# Foundations of Digital Marketing and E-commerce:
#  ['Dasar-Dasar Pemasaran Digital', 'Digital Marketing Course | Digital Marketing Tutorial', 'Digital Marketing FAQs - Common Digital Marketing Questions', 'Digital Marketing Essentials Masterclass', 'Introduction to Digital Marketing']
#
# Foundations of Finance:
#  ['Dasar-Dasar Keuangan', 'Foundations of MedicalSpanish', 'Study Case : Finance', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Fundamentos de laTecnología Blockchain']
#
# Foundations of MedicalSpanish:
#  ['Foundations of Finance', 'Fundamentos de laTecnología Blockchain', 'Mempelajari Analitik Data: 1 Fondasi', 'Media Fundamentals', 'Dasar-Dasar Keuangan']
#
# Francés Introductorio:
#  ['Introduction to FinTech', 'Statistics Introduction', 'Introduction to Statistics', 'Introduction to Typography', 'Marketing Introduction']
#
# From Excel to Power BI:
#  ['Data Analysis with Excel and Power BI', 'Power BI: Dasbor untuk Pemula', 'Business Analytics with Excel: Elementary to Advanced', 'Pelatihan Esensial Power BI', 'Belajar Excel: Analisis Data']
#
# Function in Python:
#  ['String in Python', 'List Fundamental in Python', 'Data Structure in Python', 'Python for Data Analysis', 'Regular Expression Python']
#
# Fundamentals Data Analysis & Decision Making Models - Theory:
#  ['Basics of Plotly for Data Analysis & Data Science', 'Data Analysis Fundamental', 'Analisis Bisnis untuk Pemula : Metode Statistik', 'Basics of Seaborn for Data Analysis & Data Science', 'Data Science Projects - Data Analysis & Machine Learning']
#
# Fundamentals of Color and Appearance:
#  ['Fundamentos deinformación financiera ycontable', 'Graphic Elements of Design: Color Theory and Image Formats', 'Fundamentals of Graphic Design', 'Media Fundamentals', 'Foundations of MedicalSpanish']
#
# Fundamentals of FinancialMathematics and CapitalBudgeting:
#  ['Fundamentos deinformación financiera ycontable', 'Financial accounting andcapital markets', 'Introduction toMathematics for Financeand Business', 'Dasar-Dasar Keuangan', 'Finanzas e inversionespara no financieros']
#
# Fundamentals of Graphic Design:
#  ['Introduction To Graphic Design', 'Introduction to Graphic Design', 'Graphic Design', "Vectr: Beginner's Guide To Graphic Design", 'Graphic Design Theory for beginners']
#
# Fundamentos de laTecnología Blockchain:
#  ['Foundations of Finance', 'Foundations of MedicalSpanish', 'Foundations of Digital Marketing and E-commerce', 'Process Mining: Data Science in Action', 'Dasar-Dasar Pemasaran Digital']
#
# Fundamentos deinformación financiera ycontable:
#  ['Fundamentals of FinancialMathematics and CapitalBudgeting', 'Dasar-Dasar Keuangan', 'Financial accounting andcapital markets', 'Financial Development andFinancial Inclusion', 'Finanzas e inversionespara no financieros']
#
# Funnelling & Media Planning:
#  ['Campaign & Media Planning', 'Creating Campaign Planning', 'Media Fundamentals', 'Preparing Your Career as Campaign Planner', 'MacroeconometricForecasting']
#
# Hierarchy and Composition:
#  ['Graphic Design: Unity and Rhythm Master Class', 'Graphic Elements of Design: Color Theory and Image Formats', 'Academic and BusinessWriting', 'Introduction and Installation', 'Cohort and Retention Analysis']
#
# Graphic Design:
#  ['Graphic Design Resources', 'Introduction to Graphic Design', 'Introduction To Graphic Design', 'Graphic Design Career Opportunity', 'Fundamentals of Graphic Design']
#
# Graphic Design - Passive Income Downloads & Self Publishing:
#  ['Graphic Design - Passive Income with Online Merchandise', 'Professional Advertising & Graphic Design [Mascot/Logo]', 'Graphic Design Resources', 'Graphic Design Career Opportunity', 'Graphic design: Designing 4 Advertisements in a series!']
#
# Graphic Design - Passive Income with Online Merchandise:
#  ['Graphic Design - Passive Income Downloads & Self Publishing', 'Graphic design: Designing 4 Advertisements in a series!', 'Graphic Design Career Opportunity', 'Graphic Design Resources', 'Graphic Design Theory for beginners']
#
# Graphic Design Basics for Educators Using Free Software:
#  ['Beginners Guide To Graphic Design Without Paid Software', "Vectr: Beginner's Guide To Graphic Design", 'Adobe Illustrator-CC Logo & Graphic Design Crash Course', 'Fundamentals of Graphic Design', 'The Ultimate Canva Course For Beginners: Graphic Design']
#
# Graphic Design Career Opportunity:
#  ['Graphic Design', 'Professional Advertising & Graphic Design [Mascot/Logo]', 'Graphic Design Resources', 'Graphic Design Theory for beginners', 'Canva Pro Graphic Design Course for Business Professionals']
#
# Graphic Design for Entrepreneurs...Who Can't Draw:
#  ['Graphic Design', 'Graphic Design Career Opportunity', 'Graphic design: Designing 4 Advertisements in a series!', 'Graphic Design Resources', 'Ideas from the History of Graphic Design']
#
# Graphic Design Resources:
#  ['Graphic Design', 'Fundamentals of Graphic Design', 'Graphic Design Career Opportunity', 'Introduction to Graphic Design', 'Introduction To Graphic Design']
#
# Graphic Design Theory for beginners:
#  ["Vectr: Beginner's Guide To Graphic Design", 'The Ultimate Canva Course For Beginners: Graphic Design', 'Introduction to Graphic Design', 'Introduction To Graphic Design', 'Ideas from the History of Graphic Design']
#
# Graphic design: Designing 4 Advertisements in a series!:
#  ['Professional Advertising & Graphic Design [Mascot/Logo]', 'Graphic Design', 'Graphic Design Career Opportunity', 'Ideas from the History of Graphic Design', 'Graphic Design Theory for beginners']
#
# Graphic design: top 6 fundamental rules to master design:
#  ['Fundamentals of Graphic Design', 'Graphic Design Theory for beginners', "Vectr: Beginner's Guide To Graphic Design", 'Graphic design: Designing 4 Advertisements in a series!', 'The Ultimate Canva Course For Beginners: Graphic Design']
#
# Graphic Design: Unity and Rhythm Master Class:
#  ['Graphic Design Theory for beginners', 'Graphic Design', 'Fundamentals of Graphic Design', 'Graphic Design Resources', 'Adobe Illustrator-CC Logo & Graphic Design Crash Course']
#
# Graphic Elements of Design: Color Theory and Image Formats:
#  ['Graphic Design Theory for beginners', 'Fundamentals of Graphic Design', "Vectr: Beginner's Guide To Graphic Design", 'Ideas from the History of Graphic Design', 'Introduction to Graphic Design']
#
# Hollywood: History,Industry, Art:
#  ['The Craft of Storytelling', 'Graphic Design Career Opportunity', 'Funnelling & Media Planning', 'Graphic Design', 'Graphic Design Resources']
#
# How to Ideate: Creative Strategy/Brief:
#  ['Creativity and Creative Block', 'Creative Brief', 'Academic English: How toWrite an Essay', "Graphic Design for Entrepreneurs...Who Can't Draw", 'Creating Integrated Marketing Plan']
#
# Hypothesis Testing:
#  ['Hypothetical Testing and AB Test', 'Correlation Analysis', 'Correlation Analysis', 'Regression and Inferential Analysis', 'Marketing Analytics: Experiment & Evaluation']
#
# Hypothetical Testing and AB Test:
#  ['Hypothesis Testing', 'IELTS Academic TestPreparation', 'Understanding the TOEFLEssentials Test', 'Cohort and Retention Analysis', 'TOEFL® Test Preparation:The Insider’s Guide']
#
# Ideas from the History of Graphic Design:
#  ['Graphic Design Theory for beginners', 'Fundamentals of Graphic Design', 'Introduction To Graphic Design', 'Introduction to Graphic Design', 'The Ultimate Canva Course For Beginners: Graphic Design']
#
# IELTS Academic TestPreparation:
#  ['Understanding the TOEFLEssentials Test', 'Academic English: How toWrite an Essay', 'Digital Marketing Essentials Masterclass', 'Kursus Digital Marketing untuk Pemula', 'Assessing Marketing Materials']
#
# Inclusive Growth: ClimateChange:
#  ['Macroeconomics ofClimate Change: ClimateRisks for the Financial Se…', 'Macroeconomics ofClimate Change: Science,Economics, and Policies', 'Macroeconomics ofClimate Change: GreenPublic Finance', 'Climate Change: FinancialRisks and Opportunities', 'Macroeconomics ofClimate Change:Economics of Adaptation']
#
# Indexing, Slicing, Filtering, and Shorting:
#  ['Cohort and Retention Analysis', 'Cohort and Retention Analysis Practice', 'Subquery and Common Table Expression', 'Table Creating and Manipulation', 'Table Reshaping']
#
# Información financiera ysu análisis:
#  ['Financial Market Analysis', 'Dasar-Dasar Keuangan', 'Revenue Forecasting andAnalysis', 'Data Analysis Fundamental', 'ChatGPT for Data Analysis']
#
# Inglés para todos: nivelbásico:
#  ['Inglés para todos: nivelbásico más', 'English for Journalists,Part 1', 'Basic Spanish 1: GettingStarted', 'Mandarin Chinese Level 1', 'Basic Spanish 2: One StepFurther']
#
# Inglés para todos: nivelbásico más:
#  ['Inglés para todos: nivelbásico', 'English for Journalists,Part 1', 'Basic Spanish 2: One StepFurther', 'Mandarin Chinese Level 1', 'Basic Spanish 1: GettingStarted']
#
# Innovation Through Design: Think, Make, Break, Repeat:
#  ['Graphic design: top 6 fundamental rules to master design', 'Ideas from the History of Graphic Design', 'Design Styles', 'Graphic Design: Unity and Rhythm Master Class', 'The Ultimate Canva Course For Beginners: Graphic Design']
#
# Inspiration: Success & Award Winning Campaigns:
#  ['Creating Campaign Planning', 'Campaign & Media Planning', 'Campaign Fundamentals', 'Brand & Creative Strategy', 'Brand Campaign Touchpoints']
#
# Intellectual Property, Copyright, License:
#  ['Paid Content Marketing', 'Designing Brand Identity', 'Branding Introduction', 'El arte de vender:introducción a las ventas', 'Logo Design']
#
# Interactive Computer Graphics:
#  ['Graphic Design', 'Introduction to Graphic Design', 'Introduction To Graphic Design', 'Beginners Guide To Graphic Design Without Paid Software', 'Graphic Design Resources']
#
# InterculturalCommunication at Work –Land the job and do it well:
#  ['Storytelling in theWorkplace', 'Soft Skills: CollaborateEffectively', 'Comunicación yRedacción Digital', 'Teamwork & Collaboration', 'Using Email forNetworking in English']
#
# Interest Rate RiskManagement in Banks/Financial Institution:
#  ['VITARA - Compliance RiskManagement', 'Macroeconomics ofClimate Change: ClimateRisks for the Financial Se…', 'Introduction to PersonalFinancial Planning', 'Introducción a lasfinanzas: Principios devaloración', 'Climate Change: FinancialRisks and Opportunities']
#
# Intro to Pandas:
#  ['Master Data Analysis with Python - Intro to Pandas', 'Pandas Datetime', 'Basics of Pandas for Data Analysis & Data Science', 'Intro to Stock Trading', 'All About Dictionary Python']
#
# Intro to Stock Trading:
#  ['Introducción a la inversiónbursátil', 'Introduction to FinTech', 'Introduction to PersonalFinancial Planning', 'Introduction toMathematics for Financeand Business', 'Analisis Bisnis untuk Pemula : Metode Statistik']
#
# Introducción a la inversiónbursátil:
#  ['Intro to Stock Trading', 'Introduction to FinTech', 'Introduction to PersonalFinancial Planning', 'Introduction to Statistics', 'Marketing Introduction']
#
# Introducción a lasfinanzas: Principios devaloración:
#  ['Introduction to FinTech', 'Introduction toMathematics for Financeand Business', 'Introduction to PersonalFinancial Planning', 'Pengantar Analisis Merek Digital untuk Pemula', 'Introducción a la inversiónbursátil']
#
# Introducción al griegoclásico: lengua, nombres ymitología:
#  ['Italian Language andCulture: Advanced(2023-2024)', 'Introducción a la inversiónbursátil', 'Introduction to Typography', 'Italian Language andCulture: Beginner(2023-2024)', 'Italian Language andCulture: Intermediate(2023-2024)']
#
# Introduction and Installation:
#  ['Introduction to FinTech', 'Introduction to Statistics', 'Database Introduction', 'Statistics Introduction', 'Marketing Introduction']
#
# Introduction to book cover design. Redesigning George Orwell:
#  ['Introduction to Typography', 'Introduction To Graphic Design', 'Introduction to Graphic Design', 'Introduction to User Experience Design', "Vectr: Beginner's Guide To Graphic Design"]
#
# Introduction to Data Preprocessing:
#  ['Data Science Introduction', 'Introduction to FinTech', 'Introduction to Machine Learning', 'Introduction to Statistics', 'Database Introduction']
#
# Introduction to Digital Marketing:
#  ['Dasar-Dasar Pemasaran Digital', 'Digital Marketing Course for Beginners', 'Digital Marketing Course | Digital Marketing Tutorial', 'Digital Marketing for Beginners 2023', 'Kursus Digital Marketing untuk Pemula']
#
# Introduction to FinTech:
#  ['Introduction to Machine Learning', 'Introduction to Statistics', 'Introducción a la inversiónbursátil', 'Introduction to Graphic Design', 'Introduction To Graphic Design']
#
# Introduction To Graphic Design:
#  ['Introduction to Graphic Design', 'Fundamentals of Graphic Design', 'Introduction to Typography', 'Graphic Design Theory for beginners', 'Graphic Design']
#
# Introduction to Graphic Design:
#  ['Introduction to Graphic Design', 'Fundamentals of Graphic Design', 'Introduction to Typography', 'Graphic Design Theory for beginners', 'Graphic Design']
#
# Introduction to Machine Learning:
#  ['Introduction to FinTech', 'Data Science Introduction', 'Data Science, Machine Learning, Data Analysis, Python & R', 'Introduction to Data Preprocessing', 'Data Science Projects - Data Analysis & Machine Learning']
#
# Introduction to PersonalFinancial Planning:
#  ['Introducción a la inversiónbursátil', 'Introduction toMathematics for Financeand Business', 'Introduction to FinTech', 'Introducción a lasfinanzas: Principios devaloración', 'Dasar-Dasar Keuangan']
#
# Introduction to Statistics:
#  ['Statistics Introduction', 'Statistics', 'Introduction to FinTech', 'Introduction to Data Preprocessing', 'Data Science Introduction']
#
# Introduction to Typography:
#  ['Introduction to Graphic Design', 'Introduction To Graphic Design', 'Typography', 'Introduction to FinTech', 'Branding Introduction']
#
# Introduction to User Experience Design:
#  ['Introduction To Graphic Design', 'Introduction to Graphic Design', 'Introduction to FinTech', 'Introduction to Typography', 'Introduction to book cover design. Redesigning George Orwell']
#
# Introduction toMathematics for Financeand Business:
#  ['Fundamentals of FinancialMathematics and CapitalBudgeting', 'Introduction to PersonalFinancial Planning', 'Introducción a lasfinanzas: Principios devaloración', 'Introduction to FinTech', 'Python and Statistics for Financial Analysis']
#
# Italian Language andCulture: Advanced(2023-2024):
# ...
#
# Pengantar Analisis Data untuk Memecahkan Masalah Kualitas:
#  ['SQL for Data Analysis: Solving real-world problems with data', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'ChatGPT for Data Analysis', 'Basics of Matplotlib for Data Analysis & Data Science']
#
# Pengantar Analisis Merek Digital untuk Pemula:
#  ['Complete Introduction into Digital Marketing for Beginners', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing Course for Beginners', 'Kursus Digital Marketing untuk Pemula', 'Introduction to Digital Marketing']
#
# Population Health: Responsible Data Analysis:
#  ['ChatGPT for Data Analysis', 'Data Analysis Fundamental', 'Basics of Plotly for Data Analysis & Data Science', 'Fundamentals Data Analysis & Decision Making Models - Theory', 'Clustering Analysis']
#
# Power BI: Dasbor untuk Pemula:
#  ['Pelatihan Esensial Power BI', 'From Excel to Power BI', 'Data Analysis with Excel and Power BI', 'Finding the Brand Benefit', "Graphic Design for Entrepreneurs...Who Can't Draw"]
#
# Preparing Your Career as Campaign Planner:
#  ['Creating Campaign Planning', 'Campaign & Media Planning', 'Funnelling & Media Planning', 'Strategi Memulai Digital Marketing dari Awal', 'Introduction to PersonalFinancial Planning']
#
# Probability and Distribution:
#  ['Statistics', 'Statistics Introduction', 'Revenue Forecasting andAnalysis', 'Statistics and data literacy for non-statisticians', 'MacroeconometricForecasting']
#
# Process Mining: Data Science in Action:
#  ['Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Dasar-Dasar Ilmu Data: Penggalian Data', 'Data Science Projects - Data Analysis & Machine Learning', 'Data Science, Machine Learning, Data Analysis, Python & R']
#
# Professional Advertising & Graphic Design [Mascot/Logo]:
#  ['Canva Pro Graphic Design Course for Business Professionals', 'Graphic Design Career Opportunity', 'Graphic Design', 'Graphic design: Designing 4 Advertisements in a series!', 'Graphic Design Resources']
#
# Professional BusinessPresentations:
#  ['Business Communication', 'Canva Pro Graphic Design Course for Business Professionals', 'Business Metrics', 'Professional Advertising & Graphic Design [Mascot/Logo]', 'Business Communications- The Basics']
#
# Project: Clustering Model:
#  ['Project: Prediction Model', 'Clustering Analysis', 'Data Science Projects - Data Analysis & Machine Learning', 'Feature Engineering', 'Kepemimpinan Proyek']
#
# Project: Prediction Model:
#  ['Project: Clustering Model', 'MacroeconometricForecasting', 'Kepemimpinan Proyek', 'Hypothesis Testing', 'Fundamentals Data Analysis & Decision Making Models - Theory']
#
# Public Speaking:
#  ['Professional BusinessPresentations', 'Consumer & Audience Insight', 'Becoming an EffectiveLeader', 'Business Communication', 'Marketing Introduction']
#
# Python 101 - For Data Analysis:
#  ['Python for Data Analysis', 'Basics of Numpy for Data Analysis & Data Science', 'Python and Statistics for Financial Analysis', 'Data Science, Machine Learning, Data Analysis, Python & R', 'Master Data Analysis with Python - Intro to Pandas']
#
# Python and Statistics for Financial Analysis:
#  ['Python for Data Analysis', 'Python 101 - For Data Analysis', 'Master Data Analysis with Python - Intro to Pandas', 'Basics of Numpy for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R']
#
# Python for Data Analysis:
#  ['Python 101 - For Data Analysis', 'Python and Statistics for Financial Analysis', 'Basics of Numpy for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R', 'Master Data Analysis with Python - Intro to Pandas']
#
# Regression and Inferential Analysis:
#  ['Revenue Forecasting andAnalysis', 'Visualisasi Data untuk Analisis dan Analitik Data', 'Correlation Analysis', 'Correlation Analysis', 'Clustering Analysis']
#
# Regular Advance Expression:
#  ['Subquery and Common Table Expression', 'Line, Shape, and Form', 'Regular Expression Python', 'Leading With EffectiveCommunication (InclusiveLeadership Training)', 'Digital Platforms inPerformance']
#
# Regular Expression Python:
#  ['String in Python', 'Function in Python', 'All About Dictionary Python', 'Python for Data Analysis', 'List Fundamental in Python']
#
# Relationship and Alter Table:
#  ['Table Creating and Manipulation', 'Table Reshaping', 'Subquery and Common Table Expression', 'SQL String and Date Function', 'SQL Joins']
#
# Revenue Forecasting andAnalysis:
#  ['Regression and Inferential Analysis', 'Monetary Policy Analysisand Forecasting', 'MacroeconometricForecasting', 'Información financiera ysu análisis', 'Financial Market Analysis']
#
# Search, Match and Find All:
#  ['Metodologi Penelitian untuk Pemula', 'Finding the Brand Benefit', 'Market Research & Objective', 'Regular Expression Python', 'Fundamentals of Color and Appearance']
#
# Skills and Tools in Data Analysis:
#  ['Belajar Excel: Analisis Data', 'Visualisasi Data untuk Analisis dan Analitik Data', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'UCI Data Preprocessing and Exploratory Data Analysis']
#
# Social Media Marketing untuk Pemula:
#  ['Dasar-Dasar Pemasaran Media Sosial', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing Course for Beginners', 'Digital Marketing for Beginners 2023', 'Kursus Digital Marketing untuk Pemula']
#
# Soft Skills: CollaborateEffectively:
#  ['Soft Skills: DevelopInterpersonal Skills', 'Teamwork & Collaboration', 'Becoming an EffectiveLeader', 'Comunicación efectivapara el líder actual', 'InterculturalCommunication at Work –Land the job and do it well']
#
# Soft Skills: DevelopInterpersonal Skills:
#  ['Soft Skills: CollaborateEffectively', 'Skills and Tools in Data Analysis', 'Leaders of Learning', 'Basic Digital Marketing untuk Pemula', 'Kursus Digital Marketing untuk Pemula']
#
# SQL Advance: Group By & Agregat:
#  ['SQL Joins', 'SQL Keyword', 'SQL String and Date Function', 'Basic SQL', 'Subquery and Common Table Expression']
#
# SQL for Data Analysis: Solving real-world problems with data:
#  ['Basics of Plotly for Data Analysis & Data Science', 'Pengantar Analisis Data untuk Memecahkan Masalah Kualitas', 'ChatGPT for Data Analysis', 'Python for Data Analysis', 'Basics of Seaborn for Data Analysis & Data Science']
#
# SQL Joins:
#  ['SQL Keyword', 'SQL Advance: Group By & Agregat', 'Basic SQL', 'SQL String and Date Function', 'Case Study: Implementing SQL']
#
# SQL Keyword:
#  ['Basic SQL', 'SQL Joins', 'SQL String and Date Function', 'SQL Advance: Group By & Agregat', 'Case Study: Implementing SQL']
#
# SQL Mastery & Data Analysis - A Teaser:
#  ['SQL for Data Analysis: Solving real-world problems with data', 'Basics of Plotly for Data Analysis & Data Science', 'Visualisasi Data untuk Analisis dan Analitik Data', 'Belajar Excel: Analisis Data', 'ChatGPT for Data Analysis']
#
# SQL String and Date Function:
#  ['SQL Keyword', 'Basic SQL', 'SQL Joins', 'SQL Advance: Group By & Agregat', 'Subquery and Common Table Expression']
#
# Stand Up!; ComedyWriting and PerformancePoetry:
#  ['Cohort and Retention Analysis', 'Table Creating and Manipulation', 'Relationship and Alter Table', 'Academic and BusinessWriting', 'Hypothetical Testing and AB Test']
#
# Statistics:
#  ['Statistics Introduction', 'Introduction to Statistics', 'Statistics and data literacy for non-statisticians', 'Business Metrics', 'Correlation Analysis']
#
# Statistics and data literacy for non-statisticians:
#  ['Statistics', 'Introduction to Statistics', 'Statistics Introduction', 'Python and Statistics for Financial Analysis', 'Skills and Tools in Data Analysis']
#
# Statistics Introduction:
#  ['Introduction to Statistics', 'Statistics', 'Marketing Introduction', 'Database Introduction', 'Data Science Introduction']
#
# Steps in Japanese forBeginners1 Part1:
#  ['Mandarin ChineseEssentials', 'Mandarin Chinese forBusiness', 'Mandarin Chinese Level 1', 'Italian Language andCulture: Advanced(2023-2024)', 'Italian Language andCulture: Intermediate(2023-2024)']
#
# Stored Procedure:
#  ['SQL Joins', 'SQL Keyword', 'Basic SQL', 'SQL String and Date Function', 'Case Study: Implementing SQL']
#
# Storytelling for SocialChange:
#  ['Storytelling in theWorkplace', 'Social Media Marketing untuk Pemula', 'Dasar-Dasar Pemasaran Media Sosial', 'The Craft of Storytelling', 'KOL Management untuk Sosial Media Marketing']
#
# Storytelling in theWorkplace:
#  ['Storytelling for SocialChange', 'The Craft of Storytelling', 'Business WritingTechniques', 'Teamwork & Collaboration', 'InterculturalCommunication at Work –Land the job and do it well']
#
# Strategi Memulai Digital Marketing dari Awal:
#  ['Digital Marketing Course | Digital Marketing Tutorial', 'Basic Digital Marketing untuk Pemula', 'Complete Introduction into Digital Marketing for Beginners', 'Marketing for Entrepreneurs in 2022: Learn Digital Marketing', 'Digital Marketing Course for Beginners']
#
# String in Python:
#  ['Function in Python', 'Regular Expression Python', 'List Fundamental in Python', 'Data Structure in Python', 'All About Dictionary Python']
#
# Study Case : Finance:
#  ['Foundations of Finance', 'Financial Market Analysis', 'Información financiera ysu análisis', 'Dasar-Dasar Keuangan', 'Mempelajari Analitik Data: 1 Fondasi']
#
# Subquery and Common Table Expression:
#  ['SQL Joins', 'Relationship and Alter Table', 'SQL Advance: Group By & Agregat', 'SQL String and Date Function', 'SQL Keyword']
#
# Table Creating and Manipulation:
#  ['Relationship and Alter Table', 'Table Reshaping', 'Pelatihan Penting Tableau', 'Subquery and Common Table Expression', 'Transaction Classification of Fraud and Non Fraud']
#
# Table Reshaping:
#  ['Relationship and Alter Table', 'Table Creating and Manipulation', 'Pelatihan Penting Tableau', 'Data Visualization Seaborn', 'Data Visualization Plotly']
#
# Target Market Mapping:
#  ['Market Research & Objective', 'Creating Integrated Marketing Plan', 'Marketing Business Metrics', 'Financial Market Analysis', 'Marketing Analytics: Experiment & Evaluation']
#
# Teamwork & Collaboration:
#  ['Soft Skills: CollaborateEffectively', 'Leading High-PerformingTeams', 'Storytelling in theWorkplace', 'Kepemimpinan Proyek', 'Business Communication']
#
# Text Analysis:
#  ['Descriptive Analysis', 'Data Analysis Fundamental', 'ChatGPT for Data Analysis', 'Correlation Analysis', 'Correlation Analysis']
#
# The A-Z Digital Marketing Course - Everything Under 30min!:
#  ['Digital Marketing Essentials Masterclass', 'Digital Marketing Course | Digital Marketing Tutorial', 'Digital Marketing FAQs - Common Digital Marketing Questions', 'Digital Marketing Masterclass in 2 Hours', 'AI & ChatGPT Prompt for  Digital Marketing, Sales & Growth']
#
# The Craft of Storytelling:
#  ['Storytelling in theWorkplace', 'Storytelling for SocialChange', 'Funnelling & Media Planning', 'Hollywood: History,Industry, Art', 'Business WritingTechniques']
#
# The Language of Design: Form and Meaning:
#  ['Design Terminology', 'El cerebro y las emocionesen el lenguaje', 'Merancang dan Mengkreasikan Iklan Dengan Semiotika Visual', 'Graphic Elements of Design: Color Theory and Image Formats', 'Line, Shape, and Form']
#
# The Strategy of Content Marketing:
#  ['Content Marketing', 'Pemasaran Media Sosial: Strategi dan Pengoptimalan', 'Dasar-Dasar Pemasaran Media Sosial', 'Digital Marketing Strategy for Managers', 'Dasar-Dasar Pemasaran Digital']
#
# The Ultimate Canva Course For Beginners: Graphic Design:
#  ['Graphic Design Theory for beginners', "Vectr: Beginner's Guide To Graphic Design", 'Amazing Graphic Design for Beginners in 3 EASY STEPS', 'Learn Canva & Canva Pro - Easiest Graphic Design Course 2023', 'Beginners Guide To Graphic Design Without Paid Software']
#
# Tips dan Trik Visualisasi Data:
#  ['Data Visualization Practice', 'Data Visualization Plotly', 'Basic of Data Visualization', 'Data Visualization', 'Data Visualization Seaborn']
#
# TOEFL® Test Preparation:The Insider’s Guide:
#  ['Understanding the TOEFLEssentials Test', "Vectr: Beginner's Guide To Graphic Design", 'IELTS Academic TestPreparation', 'Hypothetical Testing and AB Test', 'Marketing Analytics: Experiment & Evaluation']
#
# Transaction Classification of Fraud and Non Fraud:
#  ['Table Creating and Manipulation', 'Fundamentos deinformación financiera ycontable', 'Finanzas e inversionespara no financieros', 'Relationship and Alter Table', 'Statistics and data literacy for non-statisticians']
#
# Typography:
#  ['Introduction to Typography', 'Graphic Design', 'Logo Design', 'Graphic Design Resources', 'Introduction to Graphic Design']
#
# UCI Data Preprocessing and Exploratory Data Analysis:
#  ['Visualisasi Data untuk Analisis dan Analitik Data', 'ChatGPT for Data Analysis', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Data Science Projects - Data Analysis & Machine Learning']
#
# Understanding Clinical Research: Behind the Statistics:
#  ['Python and Statistics for Financial Analysis', 'Population Health: Responsible Data Analysis', 'Introduction to Statistics', 'Analisis Bisnis untuk Pemula : Metode Statistik', 'Statistics and data literacy for non-statisticians']
#
# Understanding the TOEFLEssentials Test:
#  ['IELTS Academic TestPreparation', 'Digital Marketing Essentials Masterclass', 'TOEFL® Test Preparation:The Insider’s Guide', 'Academic English: How toWrite an Essay', 'Introduction to FinTech']
#
# Unlocking Investment andFinance in EmergingMarkets and Developing…:
#  ['Finanzas e inversionespara no financieros', 'Financial accounting andcapital markets', 'Fundamentos deinformación financiera ycontable', 'Financial Development andFinancial Inclusion', 'Merancang dan Mengkreasikan Iklan Dengan Semiotika Visual']
#
# Upper-IntermediateEnglish: Business andGlobalization:
#  ['Upper-IntermediateEnglish: Business andTechnology', 'Upper-IntermediateEnglish: Business andIndustry', 'Academic and BusinessWriting', 'Italian Language andCulture: Intermediate(2023-2024)', 'Italian Language andCulture: Beginner(2023-2024)']
#
# Upper-IntermediateEnglish: Business andIndustry:
#  ['Upper-IntermediateEnglish: Business andTechnology', 'Upper-IntermediateEnglish: Business andGlobalization', 'Academic and BusinessWriting', 'Introduction toMathematics for Financeand Business', 'Business WritingTechniques']
#
# Upper-IntermediateEnglish: Business andTechnology:
#  ['Upper-IntermediateEnglish: Business andIndustry', 'Upper-IntermediateEnglish: Business andGlobalization', 'Business WritingTechniques', 'Academic and BusinessWriting', 'Introduction toMathematics for Financeand Business']
#
# Using Email forNetworking in English:
#  ['Academic English: How toWrite an Essay', 'Leer y escribir en launiversidad', 'English for Journalists,Part 1', 'Email marketing: diseño ygestión de campañas', 'InterculturalCommunication at Work –Land the job and do it well']
#
# Vectr: Beginner's Guide To Graphic Design:
#  ['Graphic Design Theory for beginners', 'Beginners Guide To Graphic Design Without Paid Software', 'The Ultimate Canva Course For Beginners: Graphic Design', 'Introduction To Graphic Design', 'Introduction to Graphic Design']
#
# Visualisasi Data untuk Analisis dan Analitik Data:
#  ['ChatGPT for Data Analysis', 'Basics of Plotly for Data Analysis & Data Science', 'UCI Data Preprocessing and Exploratory Data Analysis', 'Basics of Seaborn for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science']
#
# VITARA - Compliance RiskManagement:
#  ['Interest Rate RiskManagement in Banks/Financial Institution', 'Climate Change: FinancialRisks and Opportunities', 'Population Health: Responsible Data Analysis', 'Digital Marketing Strategy for Managers', 'KOL Management untuk Sosial Media Marketing']
#
# Writing Feature Articles:
#  ['Business WritingTechniques', 'Academic and BusinessWriting', 'Comunicación yRedacción Digital', 'Text Analysis', 'Academic English: How toWrite an Essay']

# %% [markdown]
# ## Export Translated Title Embeddings to CSV

# %%
# Combine data into a list of tuples
data = list(zip(course_title, tittle_eng, judul_embeddings))

# Specify the CSV file path
csv_file_path = 'course_title_embedding.csv'

# Write data to the CSV file
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['judul kursus', 'judul kursus eng', 'embedding'])

    # Write the data rows
    writer.writerows(data)

# Display a message indicating the CSV file creation
print(f"CSV file '{csv_file_path}' has been created.")
# Out:
# CSV file 'course_title_embedding.csv' has been created.

# %% [markdown]
# ## Reading and Processing Embeddings from CSV File for Course Titles

# %%
# Read data from CSV file
with open('course_title_embedding.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')

    # Skip header row
    next(csvfile)

    # Extract data columns
    course_title = [row[0] for row in reader]
    csvfile.seek(0)

    next(csvfile)
    tittle_eng = [row[1] for row in reader]
    csvfile.seek(0)

    next(csvfile)
    judul_embedding = [row[2] for row in reader]

# Parse string embeddings into numpy arrays
judul_embedding = [np.fromstring(embedding[1:-1], sep=' ') for embedding in judul_embedding]

# Convert the list of arrays to a numpy array
judul_embedding_numpy = np.array(judul_embedding)

# %% [markdown]
# ## Text Tokenization and Embedding for Course Titles using TensorFlow

# %%
vocab_size = 1000
embedding_dim = 16
max_length = 15
trunc_type = 'post'
padding_type = 'post'
oov_tok = '<OOV>'

# Mengonversi Teks menjadi urutan Token
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok) # mengonfigurasi jumlah kata unik (termasuk kata OOV atau out-of-vocabulary) yang akan dipertahankan, dengan batas maksimum sebanyak vocab_size.
tokenizer.fit_on_texts(course_title) # mengadaptasi tokenizer ke teks yang diberikan (course_title).
sequences = tokenizer.texts_to_sequences(course_title)
padded = pad_sequences(sequences, maxlen=max_length, truncating=trunc_type, padding=padding_type)
padded = np.array(padded)

# Model Definition
model = tf.keras.models.Sequential([
    tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=512, input_length=max_length), # mengubah urutan token menjadi vektor embedding
    tf.keras.layers.GlobalAveragePooling1D(), # merata-ratakan vektor embedding untuk menghasilkan vektor representasi yang lebih sederhana.
    tf.keras.layers.Dense(512, activation='relu'), # aktivasi relu untuk memperkenalkan non-linearitas ke dalam model.
    tf.keras.layers.Dense(512)
])

# Model Compilation
model.compile(optimizer='adam', loss='mean_squared_error')

# Model Training
model.fit(padded, judul_embedding_numpy, epochs=100)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 73ms/step - loss: 0.0018
# Epoch 2/100
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0017
# Epoch 3/100
# 11/11 [==============================] - 1s 41ms/step - loss: 0.0017
# Epoch 4/100
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0016
# Epoch 5/100
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0016
# Epoch 6/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0016
# Epoch 7/100
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0016
# Epoch 8/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0015
# Epoch 9/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 10/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0014
# Epoch 11/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 12/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 13/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 14/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 15/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 16/100
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0012
# Epoch 17/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 18/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0011
# Epoch 19/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 20/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 21/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 22/100
# 11/11 [==============================] - 0s 20ms/step - loss: 9.8272e-04
# Epoch 23/100
# 11/11 [==============================] - 0s 6ms/step - loss: 9.4970e-04
# Epoch 24/100
# 11/11 [==============================] - 0s 5ms/step - loss: 9.3243e-04
# Epoch 25/100
# 11/11 [==============================] - 0s 4ms/step - loss: 8.9912e-04
# Epoch 26/100
# 11/11 [==============================] - 0s 5ms/step - loss: 8.7132e-04
# Epoch 27/100
# 11/11 [==============================] - 0s 4ms/step - loss: 8.3929e-04
# Epoch 28/100
# 11/11 [==============================] - 0s 20ms/step - loss: 8.1557e-04
# Epoch 29/100
# 11/11 [==============================] - 0s 5ms/step - loss: 7.8771e-04
# Epoch 30/100
# 11/11 [==============================] - 0s 19ms/step - loss: 7.6782e-04
# Epoch 31/100
# 11/11 [==============================] - 0s 5ms/step - loss: 7.4719e-04
# Epoch 32/100
# 11/11 [==============================] - 0s 5ms/step - loss: 7.1602e-04
# Epoch 33/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.8972e-04
# Epoch 34/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.7353e-04
# Epoch 35/100
# 11/11 [==============================] - 0s 19ms/step - loss: 6.5156e-04
# Epoch 36/100
# 11/11 [==============================] - 0s 5ms/step - loss: 6.3964e-04
# Epoch 37/100
# 11/11 [==============================] - 0s 4ms/step - loss: 6.1612e-04
# Epoch 38/100
# 11/11 [==============================] - 0s 6ms/step - loss: 5.9128e-04
# Epoch 39/100
# 11/11 [==============================] - 0s 5ms/step - loss: 5.7201e-04
# Epoch 40/100
# 11/11 [==============================] - 0s 5ms/step - loss: 5.5479e-04
# Epoch 41/100
# 11/11 [==============================] - 0s 4ms/step - loss: 5.3619e-04
# Epoch 42/100
# 11/11 [==============================] - 0s 4ms/step - loss: 5.2196e-04
# Epoch 43/100
# 11/11 [==============================] - 0s 20ms/step - loss: 5.0357e-04
# Epoch 44/100
# 11/11 [==============================] - 0s 6ms/step - loss: 4.8076e-04
# Epoch 45/100
# 11/11 [==============================] - 0s 5ms/step - loss: 4.6828e-04
# Epoch 46/100
# 11/11 [==============================] - 0s 5ms/step - loss: 4.5431e-04
# Epoch 47/100
# 11/11 [==============================] - 0s 5ms/step - loss: 4.4258e-04
# Epoch 48/100
# 11/11 [==============================] - 0s 5ms/step - loss: 4.2890e-04
# Epoch 49/100
# 11/11 [==============================] - 0s 5ms/step - loss: 4.1681e-04
# Epoch 50/100
# 11/11 [==============================] - 0s 5ms/step - loss: 3.9854e-04
# Epoch 51/100
# 11/11 [==============================] - 0s 5ms/step - loss: 3.9090e-04
# Epoch 52/100
# 11/11 [==============================] - 0s 16ms/step - loss: 3.7861e-04
# Epoch 53/100
# 11/11 [==============================] - 0s 4ms/step - loss: 3.7000e-04
# Epoch 54/100
# 11/11 [==============================] - 0s 4ms/step - loss: 3.5814e-04
# Epoch 55/100
# 11/11 [==============================] - 0s 3ms/step - loss: 3.4482e-04
# Epoch 56/100
# 11/11 [==============================] - 0s 3ms/step - loss: 3.3336e-04
# Epoch 57/100
# 11/11 [==============================] - 0s 3ms/step - loss: 3.2132e-04
# Epoch 58/100
# 11/11 [==============================] - 0s 3ms/step - loss: 3.1606e-04
# Epoch 59/100
# 11/11 [==============================] - 0s 3ms/step - loss: 3.0650e-04
# Epoch 60/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.9978e-04
# Epoch 61/100
# 11/11 [==============================] - 0s 13ms/step - loss: 2.8934e-04
# Epoch 62/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.7745e-04
# Epoch 63/100
# 11/11 [==============================] - 0s 13ms/step - loss: 2.7010e-04
# Epoch 64/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.6042e-04
# Epoch 65/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.5540e-04
# Epoch 66/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.4669e-04
# Epoch 67/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.4427e-04
# Epoch 68/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.3508e-04
# Epoch 69/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.2826e-04
# Epoch 70/100
# 11/11 [==============================] - 0s 13ms/step - loss: 2.2130e-04
# Epoch 71/100
# 11/11 [==============================] - 0s 4ms/step - loss: 2.1786e-04
# Epoch 72/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.1295e-04
# Epoch 73/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.0597e-04
# Epoch 74/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.0769e-04
# Epoch 75/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.9876e-04
# Epoch 76/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.8918e-04
# Epoch 77/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.8234e-04
# Epoch 78/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.7987e-04
# Epoch 79/100
# 11/11 [==============================] - 0s 13ms/step - loss: 1.7629e-04
# Epoch 80/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.6932e-04
# Epoch 81/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.6514e-04
# Epoch 82/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.5943e-04
# Epoch 83/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.5562e-04
# Epoch 84/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.5563e-04
# Epoch 85/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.5167e-04
# Epoch 86/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4706e-04
# Epoch 87/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4469e-04
# Epoch 88/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4250e-04
# Epoch 89/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.3689e-04
# Epoch 90/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.3499e-04
# Epoch 91/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.3380e-04
# Epoch 92/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.2899e-04
# Epoch 93/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.2352e-04
# Epoch 94/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.2473e-04
# Epoch 95/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.1803e-04
# Epoch 96/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.1692e-04
# Epoch 97/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.1251e-04
# Epoch 98/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.1026e-04
# Epoch 99/100
# 11/11 [==============================] - 0s 13ms/step - loss: 1.0892e-04
# Epoch 100/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0740e-04

# %%
judul_embedding_predict = model.predict(padded)
# Out:
# 11/11 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Save Model

# %%
model.save("model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Finding and Display the Top Similar Titles using Cosine Similarity

# %%
# Initialize a list to store top similar indices for each title
top_similarities_indices = []

# Iterate over the embeddings of predicted titles
for i, embedding in enumerate(judul_embedding_predict):
    # Calculate cosine similarities between the current title and all other titles
    similarities = cosine_similarity(embedding.reshape(1, -1), judul_embedding_predict).flatten()

    # Get the indices of the top 5 most similar titles (excluding itself)
    top_indices = np.argsort(similarities)[-6:-1][::-1]

    # Append the top indices to the list
    top_similarities_indices.append(top_indices)

# Iterate over the top similar indices for each title
for n, similar in enumerate(top_similarities_indices):
    # Create a list of similar titles based on the top indices
    judul_similar = [course_title[index] for index in similar]

    # Display the original title and its top similar titles
    print(f"{course_title[n]}\nTop Similar Titles: {judul_similar}")
    print()
# Out:
# ¡Luces, celular y acción!Crea contenidosaudiovisuales de impacto
# Top Similar Titles: ['Merancang dan Mengkreasikan Iklan Dengan Semiotika Visual', 'Graphic Elements of Design: Color Theory and Image Formats', 'Foundations of Digital Marketing and E-commerce', 'Introduction and Installation', 'Comunicación yRedacción Digital']
#
# 3D CAD Fundamental
# Top Similar Titles: ['Fundamentals of Graphic Design', 'Data Analysis Fundamental', 'Interactive Computer Graphics', 'Foundations of Finance', 'Media Fundamentals']
#
# A Fun Collage - with 30+ Examples
# Top Similar Titles: ['Learn Canva & Canva Pro - Easiest Graphic Design Course 2023', 'Inspiration: Success & Award Winning Campaigns', 'Leading High-PerformingTeams', 'Amazing Graphic Design for Beginners in 3 EASY STEPS', 'Innovation Through Design: Think, Make, Break, Repeat']
#
# A travel by SpanishAmerica: Spanish forbeginners
# Top Similar Titles: ['Basic Spanish 1: GettingStarted', 'Basic Spanish 2: One StepFurther', 'Basic Spanish 3: Gettingthere', 'Francés Introductorio', 'Pengantar Analisis Merek Digital untuk Pemula']
#
# Academic and BusinessWriting
# Top Similar Titles: ['Business WritingTechniques', 'Comunicación yRedacción Digital', 'Leer y escribir en launiversidad', 'Upper-IntermediateEnglish: Business andIndustry', 'Academic English: How toWrite an Essay']
#
# Academic English: How toWrite an Essay
# Top Similar Titles: ['Academic and BusinessWriting', 'IELTS Academic TestPreparation', 'Leer y escribir en launiversidad', 'Understanding the TOEFLEssentials Test', 'Business WritingTechniques']
#
# Administración pública yfiscal: cómo se gestionaun gobierno
# Top Similar Titles: ['Behavioral Economics andPublic Policy', 'Public Speaking', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Becoming an EffectiveLeader', 'Introduction toMathematics for Financeand Business']
#
# Adobe Illustrator-CC Logo & Graphic Design Crash Course
# Top Similar Titles: ["Vectr: Beginner's Guide To Graphic Design", 'Beginners Guide To Graphic Design Without Paid Software', 'Graphic Design Theory for beginners', 'Adobe Photoshop: Designing Instastories', 'Introduction to Graphic Design']
#
# Adobe Photoshop Introduction
# Top Similar Titles: ['Adobe Photoshop: Selection', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Layer System', 'Adobe Photoshop: Designing Instastories']
#
# Adobe Photoshop: Brush Tools
# Top Similar Titles: ['Adobe Photoshop: Type Tools', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Layer System']
#
# Adobe Photoshop: Color Gradient
# Top Similar Titles: ['Adobe Photoshop: Coloring', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Designing Instastories']
#
# Adobe Photoshop: Coloring
# Top Similar Titles: ['Adobe Photoshop: Selection', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Color Gradient', 'Adobe Photoshop: Layer System']
#
# Adobe Photoshop: Designing Instastories
# Top Similar Titles: ['Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Layer System', 'Adobe Photoshop: Color Gradient']
#
# Adobe Photoshop: Digital Imaging Photo Manipulation
# Top Similar Titles: ['Adobe Photoshop: Digital Imaging Photo Retouching', 'Adobe Photoshop: Digital Imaging Product Showcase', 'Adobe Photoshop: Digital Imaging Poster Ads', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Designing Instastories']
#
# Adobe Photoshop: Digital Imaging Photo Retouching
# Top Similar Titles: ['Adobe Photoshop: Digital Imaging Photo Manipulation', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Digital Imaging Product Showcase', 'Adobe Photoshop: Digital Imaging Poster Ads', 'Adobe Photoshop: Coloring']
#
# Adobe Photoshop: Digital Imaging Poster Ads
# Top Similar Titles: ['Adobe Photoshop: Digital Imaging Product Showcase', 'Adobe Photoshop: Digital Imaging Photo Manipulation', 'Adobe Photoshop: Digital Imaging Photo Retouching', 'Adobe Photoshop: Designing Instastories', 'Adobe Photoshop: Duotone Effect']
#
# Adobe Photoshop: Digital Imaging Product Showcase
# Top Similar Titles: ['Adobe Photoshop: Digital Imaging Poster Ads', 'Adobe Photoshop: Digital Imaging Photo Manipulation', 'Adobe Photoshop: Digital Imaging Photo Retouching', 'Adobe Photoshop: Product Photo Retouching', 'Adobe Photoshop: Designing Instastories']
#
# Adobe Photoshop: Duotone Effect
# Top Similar Titles: ['Adobe Photoshop: Coloring', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Designing Instastories', 'Adobe Photoshop: Layer System', 'Adobe Photoshop: Color Gradient']
#
# Adobe Photoshop: Layer Mask & Layer Style
# Top Similar Titles: ['Adobe Photoshop: Layer System', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Color Gradient', 'Adobe Photoshop: Selection']
#
# Adobe Photoshop: Layer System
# Top Similar Titles: ['Adobe Photoshop: Selection', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Designing Instastories', 'Adobe Photoshop: Layer Mask & Layer Style']
#
# Adobe Photoshop: Product Photo Retouching
# Top Similar Titles: ['Adobe Photoshop: Digital Imaging Photo Retouching', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Color Gradient']
#
# Adobe Photoshop: Selection
# Top Similar Titles: ['Adobe Photoshop: Coloring', 'Adobe Photoshop: Duotone Effect', 'Adobe Photoshop: Layer System', 'Adobe Photoshop: Type Tools', 'Adobe Photoshop: Brush Tools']
#
# Adobe Photoshop: Type Tools
# Top Similar Titles: ['Adobe Photoshop: Brush Tools', 'Adobe Photoshop: Selection', 'Adobe Photoshop: Coloring', 'Adobe Photoshop: Layer System', 'Adobe Photoshop: Product Photo Retouching']
#
# AI & ChatGPT Prompt for  Digital Marketing, Sales & Growth
# Top Similar Titles: ['Digital Marketing Course | Digital Marketing Tutorial', 'Marketing for Entrepreneurs in 2022: Learn Digital Marketing', 'Digital Marketing FAQs - Common Digital Marketing Questions', 'Strategi Memulai Digital Marketing dari Awal', 'Digital Marketing for Beginners 2023']
#
# Algoritmos yProgramación en R
# Top Similar Titles: ['Data Science, Machine Learning, Data Analysis, Python & R', 'Data Science Projects - Data Analysis & Machine Learning', 'UCI Data Preprocessing and Exploratory Data Analysis', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science']
#
# All About Dictionary Python
# Top Similar Titles: ['String in Python', 'List Fundamental in Python', 'Data Structure in Python', 'Regular Expression Python', 'Function in Python']
#
# Amazing Graphic Design for Beginners in 3 EASY STEPS
# Top Similar Titles: ['The Ultimate Canva Course For Beginners: Graphic Design', "Vectr: Beginner's Guide To Graphic Design", 'Graphic Design Theory for beginners', 'Beginners Guide To Graphic Design Without Paid Software', 'Learn Canva & Canva Pro - Easiest Graphic Design Course 2023']
#
# Analisis Bisnis untuk Pemula : Metode Statistik
# Top Similar Titles: ['Metodologi Penelitian untuk Pemula', 'Fundamentals Data Analysis & Decision Making Models - Theory', 'Python and Statistics for Financial Analysis', 'Pengantar Analisis Merek Digital untuk Pemula', 'Belajar Excel: Analisis Data']
#
# Arabic for non-ArabicSpeakers
# Top Similar Titles: ['Mandarin ChineseEssentials', 'Mandarin Chinese forBusiness', 'Mandarin Chinese Level 1', 'Basic Spanish 3: Gettingthere', 'Italian Language andCulture: Advanced(2023-2024)']
#
# Assessing Marketing Materials
# Top Similar Titles: ['Content Marketing', 'Paid Content Marketing', 'Marketing Introduction', 'Marketing Business Metrics', 'Marketing Analytics: Experiment & Evaluation']
#
# Balance of Payments andInternational InvestmentPosition Statistics
# Top Similar Titles: ['Financial accounting andcapital markets', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Climate Change: FinancialRisks and Opportunities', 'Finanzas e inversionespara no financieros', 'Analisis Bisnis untuk Pemula : Metode Statistik']
#
# Basic Digital Marketing untuk Pemula
# Top Similar Titles: ['Digital Marketing Course for Beginners', 'Kursus Digital Marketing untuk Pemula', 'Digital Marketing for Beginners 2023', 'Dasar-Dasar Pemasaran Digital', 'Complete Introduction into Digital Marketing for Beginners']
#
# Basic of Data Visualization
# Top Similar Titles: ['Data Visualization Plotly', 'Data Visualization', 'Data Visualization Type', 'Data Visualization Practice', 'Data Visualization Seaborn']
#
# Basic Spanish 1: GettingStarted
# Top Similar Titles: ['Basic Spanish 3: Gettingthere', 'Basic Spanish 2: One StepFurther', 'A travel by SpanishAmerica: Spanish forbeginners', 'Francés Introductorio', 'English for Journalists,Part 1']
#
# Basic Spanish 2: One StepFurther
# Top Similar Titles: ['Basic Spanish 1: GettingStarted', 'Basic Spanish 3: Gettingthere', 'A travel by SpanishAmerica: Spanish forbeginners', 'Inglés para todos: nivelbásico más', 'Inglés para todos: nivelbásico']
#
# Basic Spanish 3: Gettingthere
# Top Similar Titles: ['Basic Spanish 1: GettingStarted', 'Basic Spanish 2: One StepFurther', 'A travel by SpanishAmerica: Spanish forbeginners', 'Basic SQL', 'Mandarin ChineseEssentials']
#
# Basic SQL
# Top Similar Titles: ['SQL Keyword', 'SQL Joins', 'Database Introduction', 'Case Study: Implementing SQL', 'SQL String and Date Function']
#
# Basics of Matplotlib for Data Analysis & Data Science
# Top Similar Titles: ['Basics of Seaborn for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R']
#
# Basics of Numpy for Data Analysis & Data Science
# Top Similar Titles: ['Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R']
#
# Basics of Pandas for Data Analysis & Data Science
# Top Similar Titles: ['Basics of Numpy for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Plotly for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R']
#
# Basics of Plotly for Data Analysis & Data Science
# Top Similar Titles: ['Basics of Seaborn for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science', 'Data Science Projects - Data Analysis & Machine Learning']
#
# Basics of Seaborn for Data Analysis & Data Science
# Top Similar Titles: ['Basics of Plotly for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R']
#
# Becoming a SuccessfulLeader (InclusiveLeadership Training)
# Top Similar Titles: ['Leading With EffectiveCommunication (InclusiveLeadership Training)', 'Becoming an EffectiveLeader', 'Kursus Digital Marketing untuk Pemula', 'Pelatihan Esensial Power BI', 'Pelatihan Penting Tableau']
#
# Becoming an EffectiveLeader
# Top Similar Titles: ['Comunicación efectivapara el líder actual', 'Leaders of Learning', 'Becoming a SuccessfulLeader (InclusiveLeadership Training)', 'Kepemimpinan Proyek', 'Leading High-PerformingTeams']
#
# Beginners Guide To Graphic Design Without Paid Software
# Top Similar Titles: ["Vectr: Beginner's Guide To Graphic Design", 'Graphic Design Basics for Educators Using Free Software', 'Graphic Design Theory for beginners', 'Adobe Illustrator-CC Logo & Graphic Design Crash Course', 'The Ultimate Canva Course For Beginners: Graphic Design']
#
# Behavioral Economics andPublic Policy
# Top Similar Titles: ['Monetary Policy Analysisand Forecasting', 'Principios de Economíaaplicados a Negocios', 'Principios de Economía', 'Macroeconomics ofClimate Change: Science,Economics, and Policies', 'Academic and BusinessWriting']
#
# Belajar Excel: Analisis Data
# Top Similar Titles: ['Data Analysis with Excel and Power BI', 'ChatGPT for Data Analysis', 'Business Analytics with Excel: Elementary to Advanced', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science']
#
# Brand & Creative Strategy
# Top Similar Titles: ['Brand Guideline Design', 'Brand Identity Design', 'Designing Brand Identity', 'Brand Campaign Touchpoints', 'Digital Marketing Strategy for Managers']
#
# Brand Campaign Touchpoints
# Top Similar Titles: ['Brand & Creative Strategy', 'Campaign Fundamentals', 'Branding Introduction', 'Brand Positioning Introduction', 'Campaign & Media Planning']
#
# Brand Guideline Design
# Top Similar Titles: ['Brand Identity Design', 'Designing Brand Identity', 'Brand Positioning Introduction', 'Design Terminology', 'Brand & Creative Strategy']
#
# Brand Identity Design
# Top Similar Titles: ['Designing Brand Identity', 'Brand Guideline Design', 'Branding Introduction', 'Brand & Creative Strategy', 'Logo Design']
#
# Brand Positioning Introduction
# Top Similar Titles: ['Branding Introduction', 'Brand Guideline Design', 'Marketing Introduction', 'Brand Identity Design', 'Brand Campaign Touchpoints']
#
# Branding Introduction
# Top Similar Titles: ['Brand Positioning Introduction', 'Marketing Introduction', 'Introduction to Typography', 'Brand Identity Design', 'Introduction to Graphic Design']
#
# Building stakeholder value
# Top Similar Titles: ['Assessing Marketing Materials', 'Pelatihan Penting Tableau', 'Creating Campaign Planning', 'Creating Integrated Marketing Plan', 'Brand & Creative Strategy']
#
# Cohort and Retention Analysis Practice
# Top Similar Titles: ['Cohort and Retention Analysis', 'Regression and Inferential Analysis', 'Clustering Analysis', 'Marketing Analytics: Experiment & Evaluation', 'Analisis Bisnis untuk Pemula : Metode Statistik']
#
# Colours
# Top Similar Titles: ['Typography', 'Descriptive Analysis', 'Design Styles', 'Logo Design', 'Graphic Design']
#
# Business Analytics with Excel: Elementary to Advanced
# Top Similar Titles: ['Belajar Excel: Analisis Data', 'Data Analysis with Excel and Power BI', 'From Excel to Power BI', 'Data Analytics for Lean Six Sigma', 'Basics of Plotly for Data Analysis & Data Science']
#
# Business Communication
# Top Similar Titles: ['Business Communications- The Basics', 'Data Communication', 'Business Metrics', 'Business WritingTechniques', 'Professional BusinessPresentations']
#
# Business Communications- The Basics
# Top Similar Titles: ['Business Communication', 'Data Communication', 'Media Fundamentals', 'Professional BusinessPresentations', 'Business WritingTechniques']
#
# Business Metrics
# Top Similar Titles: ['Marketing Business Metrics', 'Business Communication', 'Statistics', 'Professional BusinessPresentations', 'Marketing Analytics: Experiment & Evaluation']
#
# Business WritingTechniques
# Top Similar Titles: ['Academic and BusinessWriting', 'Business Communication', 'Writing Feature Articles', 'Professional BusinessPresentations', 'Upper-IntermediateEnglish: Business andTechnology']
#
# Campaign & Media Planning
# Top Similar Titles: ['Funnelling & Media Planning', 'Creating Campaign Planning', 'Preparing Your Career as Campaign Planner', 'Campaign Monitoring & Optimization', 'Campaign Fundamentals']
#
# Campaign Fundamentals
# Top Similar Titles: ['Media Fundamentals', 'Brand Campaign Touchpoints', 'Campaign & Media Planning', 'Creating Campaign Planning', 'Campaign Monitoring & Optimization']
#
# Campaign Monitoring & Optimization
# Top Similar Titles: ['Campaign & Media Planning', 'Creating Campaign Planning', 'Campaign Fundamentals', 'Pemasaran Media Sosial: Strategi dan Pengoptimalan', 'Brand Campaign Touchpoints']
#
# Canva Pro Graphic Design Course for Business Professionals
# Top Similar Titles: ['Professional Advertising & Graphic Design [Mascot/Logo]', 'Learn Canva & Canva Pro - Easiest Graphic Design Course 2023', 'Graphic Design Career Opportunity', 'The Ultimate Canva Course For Beginners: Graphic Design', 'Beginners Guide To Graphic Design Without Paid Software']
#
# Case Study: Implementing SQL
# Top Similar Titles: ['SQL Joins', 'Basic SQL', 'SQL Keyword', 'SQL for Data Analysis: Solving real-world problems with data', 'Study Case : Finance']
#
# ChatGPT for Data Analysis
# Top Similar Titles: ['Data Analysis Fundamental', 'Basics of Plotly for Data Analysis & Data Science', 'Visualisasi Data untuk Analisis dan Analitik Data', 'Basics of Seaborn for Data Analysis & Data Science', 'UCI Data Preprocessing and Exploratory Data Analysis']
#
# Climate Change: FinancialRisks and Opportunities
# Top Similar Titles: ['Macroeconomics ofClimate Change: ClimateRisks for the Financial Se…', 'Macroeconomics ofClimate Change: Science,Economics, and Policies', 'Macroeconomics ofClimate Change: GreenPublic Finance', 'Inclusive Growth: ClimateChange', 'Financial Development andFinancial Inclusion']
#
# Clustering Analysis
# Top Similar Titles: ['ChatGPT for Data Analysis', 'Data Analysis Fundamental', 'Correlation Analysis', 'Correlation Analysis', 'Project: Clustering Model']
#
# Cohort and Retention Analysis
# Top Similar Titles: ['Cohort and Retention Analysis Practice', 'Regression and Inferential Analysis', 'Clustering Analysis', 'Revenue Forecasting andAnalysis', 'ChatGPT for Data Analysis']
#
# Complete Introduction into Digital Marketing for Beginners
# Top Similar Titles: ['Digital Marketing Course for Beginners', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing for Beginners 2023', 'Kursus Digital Marketing untuk Pemula', 'Introduction to Digital Marketing']
#
# Comunicación efectivapara el líder actual
# Top Similar Titles: ['Becoming an EffectiveLeader', 'El poder de lacomunicación consciente', 'Business Communications- The Basics', 'Business Communication', 'Kepemimpinan Proyek']
#
# Comunicación yRedacción Digital
# Top Similar Titles: ['Academic and BusinessWriting', 'Business Communication', 'Business Communications- The Basics', 'Data Communication', 'Foundations of Digital Marketing and E-commerce']
#
# Concepts of Digital Marketing: Beginner to Pro in 2 hrs-2023
# Top Similar Titles: ['Basic Digital Marketing untuk Pemula', 'Digital Marketing Course for Beginners', 'Kursus Digital Marketing untuk Pemula', 'Digital Marketing for Beginners 2023', 'Digital Marketing Course | Digital Marketing Tutorial']
#
# Consumer & Audience Insight
# Top Similar Titles: ['Public Speaking', 'Academic and BusinessWriting', 'Behavioral Economics andPublic Policy', 'Market Research & Objective', 'Pemasaran Media Sosial: Strategi dan Pengoptimalan']
#
# Content Marketing
# Top Similar Titles: ['Paid Content Marketing', 'The Strategy of Content Marketing', 'Marketing Introduction', 'Dasar-Dasar Pemasaran Media Sosial', 'Dasar-Dasar Pemasaran Digital']
#
# Correlation Analysis
# Top Similar Titles: ['Correlation Analysis', 'Clustering Analysis', 'Text Analysis', 'Descriptive Analysis', 'Regression and Inferential Analysis']
#
# Correlation Analysis
# Top Similar Titles: ['Correlation Analysis', 'Clustering Analysis', 'Text Analysis', 'Descriptive Analysis', 'Regression and Inferential Analysis']
#
# Creating Campaign Planning
# Top Similar Titles: ['Campaign & Media Planning', 'Creating Integrated Marketing Plan', 'Preparing Your Career as Campaign Planner', 'Funnelling & Media Planning', 'Campaign Monitoring & Optimization']
#
# Creating Integrated Marketing Plan
# Top Similar Titles: ['Creating Campaign Planning', 'Marketing Introduction', 'Strategi Memulai Digital Marketing dari Awal', 'Marketing Business Metrics', 'Dasar-Dasar Pemasaran Digital']
#
# Creative Brief
# Top Similar Titles: ['Creative Brief and Briefing Process', 'Creativity and Creative Block', 'How to Ideate: Creative Strategy/Brief', 'Francés Introductorio', 'Brand & Creative Strategy']
#
# Creative Brief and Briefing Process
# Top Similar Titles: ['Creative Brief', 'Creativity and Creative Block', 'Tips dan Trik Visualisasi Data', 'Fundamentals of Color and Appearance', 'Academic and BusinessWriting']
#
# Creativity and Creative Block
# Top Similar Titles: ['Creative Brief', 'Brand & Creative Strategy', 'How to Ideate: Creative Strategy/Brief', 'Creative Brief and Briefing Process', 'Comunicación yRedacción Digital']
#
# Critical Thinking &Problem Solving
# Top Similar Titles: ['SQL for Data Analysis: Solving real-world problems with data', 'Hypothesis Testing', 'Pengantar Analisis Data untuk Memecahkan Masalah Kualitas', 'Data Analysis Fundamental', 'Dasar-Dasar Keuangan']
#
# Data Communication
# Top Similar Titles: ['Business Communication', 'Data Visualization', 'Business Communications- The Basics', 'Data Visualization Type', 'Data Science Introduction']
#
# Dasar-Dasar Ilmu Data: Penggalian Data
# Top Similar Titles: ['Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Data Science Projects - Data Analysis & Machine Learning', 'Basics of Pandas for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science']
#
# Dasar-Dasar Keuangan
# Top Similar Titles: ['Foundations of Finance', 'Fundamentos deinformación financiera ycontable', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Información financiera ysu análisis', 'Financial Market Analysis']
#
# Dasar-Dasar Pemasaran Digital
# Top Similar Titles: ['Digital Marketing Essentials Masterclass', 'Digital Marketing Course | Digital Marketing Tutorial', 'Basic Digital Marketing untuk Pemula', 'Introduction to Digital Marketing', 'Dasar-Dasar Pemasaran Media Sosial']
#
# Dasar-Dasar Pemasaran Media Sosial
# Top Similar Titles: ['Dasar-Dasar Pemasaran Digital', 'Social Media Marketing untuk Pemula', 'Media Sosial dan Mobile Marketing', 'Pemasaran: Naskah Iklan untuk Media Sosial', 'Pemasaran Media Sosial: Strategi dan Pengoptimalan']
#
# Data Analysis Fundamental
# Top Similar Titles: ['ChatGPT for Data Analysis', 'Basics of Plotly for Data Analysis & Data Science', 'Clustering Analysis', 'Basics of Seaborn for Data Analysis & Data Science', 'Dasar-Dasar Ilmu Data: Penggalian Data']
#
# Data Analysis with Excel and Power BI
# Top Similar Titles: ['From Excel to Power BI', 'Belajar Excel: Analisis Data', 'Business Analytics with Excel: Elementary to Advanced', 'Visualisasi Data untuk Analisis dan Analitik Data', 'ChatGPT for Data Analysis']
#
# Data Analytics for Lean Six Sigma
# Top Similar Titles: ['Basics of Plotly for Data Analysis & Data Science', 'Data Science Projects - Data Analysis & Machine Learning', 'Visualisasi Data untuk Analisis dan Analitik Data', 'UCI Data Preprocessing and Exploratory Data Analysis', 'Basics of Seaborn for Data Analysis & Data Science']
#
# Logo Design
# Top Similar Titles: ['Graphic Design', 'Introduction To Graphic Design', 'Introduction to Graphic Design', 'Graphic Design Resources', 'Typography']
#
# Data Preparation in Database
# Top Similar Titles: ['Database Introduction', 'Data Science Introduction', 'Introduction to Data Preprocessing', 'ChatGPT for Data Analysis', 'Data Analysis Fundamental']
#
# Data Science Introduction
# Top Similar Titles: ['Introduction to Data Preprocessing', 'Introduction to Machine Learning', 'Database Introduction', 'Basics of Plotly for Data Analysis & Data Science', 'Introduction to FinTech']
#
# Data Science Projects - Data Analysis & Machine Learning
# Top Similar Titles: ['Data Science, Machine Learning, Data Analysis, Python & R', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science']
#
# Data Science, Machine Learning, Data Analysis, Python & R
# Top Similar Titles: ['Data Science Projects - Data Analysis & Machine Learning', 'Basics of Numpy for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Plotly for Data Analysis & Data Science']
#
# Data Structure in Python
# Top Similar Titles: ['Python for Data Analysis', 'Function in Python', 'String in Python', 'List Fundamental in Python', 'Python 101 - For Data Analysis']
#
# Data Visualization
# Top Similar Titles: ['Data Visualization Plotly', 'Data Visualization Seaborn', 'Data Visualization Type', 'Data Visualization Practice', 'Data Visualization Bokeh']
#
# Data Visualization Bokeh
# Top Similar Titles: ['Data Visualization', 'Data Visualization Seaborn', 'Data Visualization Plotly', 'Data Visualization Matplotlib', 'Data Visualization Type']
#
# Data Visualization Matplotlib
# Top Similar Titles: ['Data Visualization Seaborn', 'Data Visualization Plotly', 'Data Visualization Bokeh', 'Data Visualization', 'Data Visualization Type']
#
# Data Visualization Plotly
# Top Similar Titles: ['Data Visualization', 'Data Visualization Seaborn', 'Data Visualization Type', 'Data Visualization Practice', 'Data Visualization Bokeh']
#
# Data Visualization Practice
# Top Similar Titles: ['Data Visualization', 'Data Visualization Plotly', 'Data Visualization Type', 'Data Visualization Seaborn', 'Basic of Data Visualization']
#
# Data Visualization Seaborn
# Top Similar Titles: ['Data Visualization Plotly', 'Data Visualization', 'Data Visualization Matplotlib', 'Data Visualization Bokeh', 'Data Visualization Type']
#
# Data Visualization Type
# Top Similar Titles: ['Data Visualization', 'Data Visualization Plotly', 'Data Visualization Practice', 'Data Visualization Seaborn', 'Basic of Data Visualization']
#
# Database Introduction
# Top Similar Titles: ['Data Preparation in Database', 'Data Science Introduction', 'Introduction to Data Preprocessing', 'Introduction to FinTech', 'Basic SQL']
#
# Dataframe Aggregate
# Top Similar Titles: ['Dataframe Merge', 'Foundations of Data Science: K-Means Clustering in Python', 'Basics of Pandas for Data Analysis & Data Science', 'SQL Advance: Group By & Agregat', 'Basics of Numpy for Data Analysis & Data Science']
#
# Dataframe Merge
# Top Similar Titles: ['Dataframe Aggregate', 'Foundations of Data Science: K-Means Clustering in Python', 'Pandas Datetime', 'Data Structure in Python', 'Basics of Pandas for Data Analysis & Data Science']
#
# Datetime
# Top Similar Titles: ['Pandas Datetime', 'SQL String and Date Function', 'SQL Keyword', 'MacroeconometricForecasting', 'String in Python']
#
# Descriptive Analysis
# Top Similar Titles: ['Text Analysis', 'Clustering Analysis', 'Data Analysis Fundamental', 'Correlation Analysis', 'Correlation Analysis']
#
# Design Element
# Top Similar Titles: ['Design Styles', 'Design Principles', 'Design Terminology', 'Logo Design', 'Brand Identity Design']
#
# Design Principles
# Top Similar Titles: ['Design Styles', 'Design Terminology', 'Design Element', 'Principios de Economía', 'Fundamentals of Graphic Design']
#
# Design Styles
# Top Similar Titles: ['Design Terminology', 'Design Element', 'Design Principles', 'Logo Design', 'Graphic Design']
#
# Design Terminology
# Top Similar Titles: ['Design Styles', 'Design Principles', 'Brand Guideline Design', 'Design Element', 'Graphic Design']
#
# Designing Brand Identity
# Top Similar Titles: ['Brand Identity Design', 'Brand Guideline Design', 'Brand & Creative Strategy', 'Branding Introduction', 'Logo Design']
#
# Digital Marketing Course | Digital Marketing Tutorial
# Top Similar Titles: ['Digital Marketing Course for Beginners', 'Kursus Digital Marketing untuk Pemula', 'Dasar-Dasar Pemasaran Digital', 'Digital Marketing FAQs - Common Digital Marketing Questions', 'Digital Marketing for Beginners 2023']
#
# Digital Marketing Course for Beginners
# Top Similar Titles: ['Kursus Digital Marketing untuk Pemula', 'Digital Marketing for Beginners 2023', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing Course | Digital Marketing Tutorial', 'Complete Introduction into Digital Marketing for Beginners']
#
# Digital Marketing Essentials Masterclass
# Top Similar Titles: ['Dasar-Dasar Pemasaran Digital', 'Digital Marketing Course | Digital Marketing Tutorial', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing Course for Beginners', 'Kursus Digital Marketing untuk Pemula']
#
# Digital Marketing FAQs - Common Digital Marketing Questions
# Top Similar Titles: ['Digital Marketing Course | Digital Marketing Tutorial', 'Dasar-Dasar Pemasaran Digital', 'Digital Marketing Essentials Masterclass', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing for Beginners 2023']
#
# Digital Marketing for Beginners 2023
# Top Similar Titles: ['Digital Marketing Course for Beginners', 'Kursus Digital Marketing untuk Pemula', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing Course | Digital Marketing Tutorial', 'Complete Introduction into Digital Marketing for Beginners']
#
# Digital Marketing for Plumbers | Plumbing Marketing 2023
# Top Similar Titles: ['Marketing for Entrepreneurs in 2022: Learn Digital Marketing', 'Digital Marketing for Beginners 2023', 'Digital Marketing Course | Digital Marketing Tutorial', 'Pemasaran: Naskah Iklan untuk Media Sosial', 'Kursus Digital Marketing untuk Pemula']
#
# Digital Marketing Masterclass in 2 Hours
# Top Similar Titles: ['Digital Marketing Essentials Masterclass', 'Digital Marketing Course | Digital Marketing Tutorial', 'Digital Marketing for Beginners 2023', 'Digital Marketing Course for Beginners', 'Dasar-Dasar Pemasaran Digital']
#
# Digital Marketing Strategy for Managers
# Top Similar Titles: ['Dasar-Dasar Pemasaran Digital', 'Strategi Memulai Digital Marketing dari Awal', 'Digital Marketing Course | Digital Marketing Tutorial', 'The Strategy of Content Marketing', 'Digital Marketing FAQs - Common Digital Marketing Questions']
#
# Digital Marketing Strategy with Goldman Sachs 10,000 Women
# Top Similar Titles: ['Digital Marketing Strategy for Managers', 'Digital Marketing Masterclass in 2 Hours', 'Digital Marketing Course | Digital Marketing Tutorial', 'Strategi Memulai Digital Marketing dari Awal', 'Marketing for Entrepreneurs in 2022: Learn Digital Marketing']
#
# Digital Performance Marketing: Tips Memulai Beriklan Online
# Top Similar Titles: ['Digital Marketing Course | Digital Marketing Tutorial', 'Strategi Memulai Digital Marketing dari Awal', 'Complete Introduction into Digital Marketing for Beginners', 'Digital Marketing for Beginners 2023', 'Digital Marketing Course for Beginners']
#
# Digital Platforms inPerformance
# Top Similar Titles: ['Digital Performance Marketing: Tips Memulai Beriklan Online', 'Campaign Monitoring & Optimization', 'Kursus Digital Marketing untuk Pemula', 'Interactive Computer Graphics', 'Digital Marketing Essentials Masterclass']
#
# Economics: ConsumerDemand
# Top Similar Titles: ['Feature Extraction', 'Market Research & Objective', 'Principios de Economía', 'Regular Advance Expression', 'Colours']
#
# Edición de vídeo ypostproducción conDaVinci Resolve. Básico
# Top Similar Titles: ['Interactive Computer Graphics', 'Media Fundamentals', 'Professional Advertising & Graphic Design [Mascot/Logo]', 'Steps in Japanese forBeginners1 Part1', 'Adobe Illustrator-CC Logo & Graphic Design Crash Course']
#
# El arte de vender:introducción a las ventas
# Top Similar Titles: ['Marketing Introduction', 'Introduction to Digital Marketing', 'Introducción a lasfinanzas: Principios devaloración', 'Introducción a la inversiónbursátil', 'Complete Introduction into Digital Marketing for Beginners']
#
# El cerebro y las emocionesen el lenguaje
# Top Similar Titles: ['The Language of Design: Form and Meaning', 'El poder de lacomunicación consciente', 'Italian Language andCulture: Beginner(2023-2024)', 'Italian Language andCulture: Advanced(2023-2024)', 'Italian Language andCulture: Intermediate(2023-2024)']
#
# El poder de lacomunicación consciente
# Top Similar Titles: ['Data Communication', 'Business Communication', 'Comunicación efectivapara el líder actual', 'Business Communications- The Basics', 'El cerebro y las emocionesen el lenguaje']
#
# Email marketing: diseño ygestión de campañas
# Top Similar Titles: ['Marketing for Entrepreneurs in 2022: Learn Digital Marketing', 'Digital Marketing Strategy for Managers', 'Digital Marketing Course | Digital Marketing Tutorial', 'Foundations of Digital Marketing and E-commerce', 'Media Sosial dan Mobile Marketing']
#
# English for Journalists,Part 1
# Top Similar Titles: ['Inglés para todos: nivelbásico', 'Inglés para todos: nivelbásico más', 'Basic Spanish 1: GettingStarted', 'Mandarin Chinese Level 1', 'Francés Introductorio']
#
# Entrepreneurship Skala Lokal hingga Global
# Top Similar Titles: ['Upper-IntermediateEnglish: Business andGlobalization', 'Launch Your Online Business', 'Launch Your Online Business', 'Inspiration: Success & Award Winning Campaigns', 'Strategi Memulai Digital Marketing dari Awal']
#
# Evaluating Impact in Low-and Middle-IncomeCountries
# Top Similar Titles: ['Assessing Marketing Materials', 'Building stakeholder value', 'Using Email forNetworking in English', 'Campaign Monitoring & Optimization', 'Entrepreneurship Skala Lokal hingga Global']
#
# Principios de Economíaaplicados a Negocios
# Top Similar Titles: ['Principios de Economía', 'Behavioral Economics andPublic Policy', 'Design Principles', 'Analisis Bisnis untuk Pemula : Metode Statistik', 'Introducción a lasfinanzas: Principios devaloración']
#
# Facebook Ads: Cómoutilizar el poder de lapublicidad en Facebook
# Top Similar Titles: ['Pemasaran: Naskah Iklan untuk Media Sosial', 'Digital Performance Marketing: Tips Memulai Beriklan Online', 'Social Media Marketing untuk Pemula', 'Digital Marketing FAQs - Common Digital Marketing Questions', 'Pemasaran Media Sosial: Strategi dan Pengoptimalan']
#
# Feature Engineering
# Top Similar Titles: ['Feature Extraction', 'Design Element', 'Design Principles', 'Design Terminology', 'Project: Clustering Model']
#
# Feature Extraction
# Top Similar Titles: ['Feature Engineering', 'Descriptive Analysis', 'Economics:\xa0ConsumerDemand', 'Clustering Analysis', 'Project: Clustering Model']
#
# Financial accounting andcapital markets
# Top Similar Titles: ['Financial Market Analysis', 'Finanzas e inversionespara no financieros', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Fundamentos deinformación financiera ycontable', 'Financial Development andFinancial Inclusion']
#
# Financial Development andFinancial Inclusion
# Top Similar Titles: ['Finanzas e inversionespara no financieros', 'Fundamentos deinformación financiera ycontable', 'Dasar-Dasar Keuangan', 'Financial accounting andcapital markets', 'Financial Programmingand Policies, Part 1:Macroeconomic Account…']
#
# Financial Market Analysis
# Top Similar Titles: ['Información financiera ysu análisis', 'Data Analysis Fundamental', 'Financial accounting andcapital markets', 'Study Case : Finance', 'Descriptive Analysis']
#
# Financial Programmingand Policies, Part 1:Macroeconomic Account…
# Top Similar Titles: ['Financial Development andFinancial Inclusion', 'Financial accounting andcapital markets', 'Finanzas e inversionespara no financieros', 'Introduction to PersonalFinancial Planning', 'Fundamentals of FinancialMathematics and CapitalBudgeting']
#
# Finanzas e inversionespara no financieros
# Top Similar Titles: ['Financial accounting andcapital markets', 'Financial Development andFinancial Inclusion', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Fundamentos deinformación financiera ycontable', 'Dasar-Dasar Keuangan']
#
# Finding the Brand Benefit
# Top Similar Titles: ['Brand Identity Design', 'Brand Positioning Introduction', 'Designing Brand Identity', 'Brand Guideline Design', 'Branding Introduction']
#
# Foundations of Data Science: K-Means Clustering in Python
# Top Similar Titles: ['Basics of Numpy for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R', 'Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Pandas for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science']
#
# Foundations of Digital Marketing and E-commerce
# Top Similar Titles: ['Dasar-Dasar Pemasaran Digital', 'Digital Marketing Course | Digital Marketing Tutorial', 'Digital Marketing FAQs - Common Digital Marketing Questions', 'Digital Marketing Essentials Masterclass', 'Introduction to Digital Marketing']
#
# Foundations of Finance
# Top Similar Titles: ['Foundations of MedicalSpanish', 'Dasar-Dasar Keuangan', 'Study Case : Finance', 'Fundamentals of FinancialMathematics and CapitalBudgeting', 'Fundamentos de laTecnología Blockchain']
#
# Foundations of MedicalSpanish
# Top Similar Titles: ['Foundations of Finance', 'Fundamentos de laTecnología Blockchain', 'Media Fundamentals', 'Mempelajari Analitik Data: 1 Fondasi', 'Dasar-Dasar Keuangan']
#
# Francés Introductorio
# Top Similar Titles: ['Introduction to FinTech', 'Statistics Introduction', 'Introduction to Statistics', 'Marketing Introduction', 'Database Introduction']
#
# From Excel to Power BI
# Top Similar Titles: ['Data Analysis with Excel and Power BI', 'Power BI: Dasbor untuk Pemula', 'Business Analytics with Excel: Elementary to Advanced', 'Belajar Excel: Analisis Data', 'Pelatihan Esensial Power BI']
#
# Function in Python
# Top Similar Titles: ['String in Python', 'List Fundamental in Python', 'Data Structure in Python', 'Regular Expression Python', 'Python for Data Analysis']
#
# Fundamentals Data Analysis & Decision Making Models - Theory
# Top Similar Titles: ['Data Analysis Fundamental', 'Basics of Plotly for Data Analysis & Data Science', 'Analisis Bisnis untuk Pemula : Metode Statistik', 'Data Science Projects - Data Analysis & Machine Learning', 'Basics of Seaborn for Data Analysis & Data Science']
#
# Fundamentals of Color and Appearance
# Top Similar Titles: ['Media Fundamentals', 'Graphic Elements of Design: Color Theory and Image Formats', 'Fundamentos deinformación financiera ycontable', 'Fundamentals of Graphic Design', 'Foundations of MedicalSpanish']
#
# Fundamentals of FinancialMathematics and CapitalBudgeting
# Top Similar Titles: ['Fundamentos deinformación financiera ycontable', 'Dasar-Dasar Keuangan', 'Financial accounting andcapital markets', 'Introduction toMathematics for Financeand Business', 'Finanzas e inversionespara no financieros']
#
# Fundamentals of Graphic Design
# Top Similar Titles: ['Graphic Design', 'Introduction to Graphic Design', 'Introduction To Graphic Design', 'Graphic Design Resources', 'Graphic Design Theory for beginners']
#
# Fundamentos de laTecnología Blockchain
# Top Similar Titles: ['Foundations of MedicalSpanish', 'Foundations of Finance', 'Foundations of Digital Marketing and E-commerce', 'Process Mining: Data Science in Action', 'Dasar-Dasar Pemasaran Digital']
#
# Fundamentos deinformación financiera ycontable
# Top Similar Titles: ['Fundamentals of FinancialMathematics and CapitalBudgeting', 'Dasar-Dasar Keuangan', 'Financial accounting andcapital markets', 'Financial Development andFinancial Inclusion', 'Finanzas e inversionespara no financieros']
#
# Funnelling & Media Planning
# Top Similar Titles: ['Campaign & Media Planning', 'Creating Campaign Planning', 'Media Fundamentals', 'Preparing Your Career as Campaign Planner', 'MacroeconometricForecasting']
#
# Hierarchy and Composition
# Top Similar Titles: ['Graphic Design: Unity and Rhythm Master Class', 'Academic and BusinessWriting', 'Introduction and Installation', 'Graphic Elements of Design: Color Theory and Image Formats', 'Design Element']
#
# Graphic Design
# Top Similar Titles: ['Graphic Design Resources', 'Introduction to Graphic Design', 'Introduction To Graphic Design', 'Logo Design', 'Graphic Design Career Opportunity']
#
# Graphic Design - Passive Income Downloads & Self Publishing
# Top Similar Titles: ['Graphic Design - Passive Income with Online Merchandise', 'Graphic Design Resources', 'Professional Advertising & Graphic Design [Mascot/Logo]', 'Graphic Design Career Opportunity', 'Beginners Guide To Graphic Design Without Paid Software']
#
# Graphic Design - Passive Income with Online Merchandise
# Top Similar Titles: ['Graphic Design - Passive Income Downloads & Self Publishing', 'Graphic design: Designing 4 Advertisements in a series!', 'Graphic Design Resources', 'Graphic Design Career Opportunity', 'Graphic Design']
#
# Graphic Design Basics for Educators Using Free Software
# Top Similar Titles: ['Beginners Guide To Graphic Design Without Paid Software', "Vectr: Beginner's Guide To Graphic Design", 'Adobe Illustrator-CC Logo & Graphic Design Crash Course', 'Graphic Design Theory for beginners', 'The Ultimate Canva Course For Beginners: Graphic Design']
#
# Graphic Design Career Opportunity
# Top Similar Titles: ['Graphic Design', 'Professional Advertising & Graphic Design [Mascot/Logo]', 'Graphic Design Resources', 'Graphic Design Theory for beginners', 'Canva Pro Graphic Design Course for Business Professionals']
#
# Graphic Design for Entrepreneurs...Who Can't Draw
# Top Similar Titles: ['Graphic Design', 'Graphic Design Career Opportunity', 'Graphic Design Resources', 'Ideas from the History of Graphic Design', 'Graphic Design Theory for beginners']
#
# Graphic Design Resources
# Top Similar Titles: ['Graphic Design', 'Fundamentals of Graphic Design', 'Graphic Design Career Opportunity', 'Introduction to Graphic Design', 'Introduction To Graphic Design']
#
# Graphic Design Theory for beginners
# Top Similar Titles: ["Vectr: Beginner's Guide To Graphic Design", 'The Ultimate Canva Course For Beginners: Graphic Design', 'Introduction to Graphic Design', 'Introduction To Graphic Design', 'Graphic Design']
#
# Graphic design: Designing 4 Advertisements in a series!
# Top Similar Titles: ['Professional Advertising & Graphic Design [Mascot/Logo]', 'Graphic Design', 'Graphic Design Resources', 'Graphic Design Career Opportunity', 'Graphic Design Theory for beginners']
#
# Graphic design: top 6 fundamental rules to master design
# Top Similar Titles: ['Fundamentals of Graphic Design', 'Graphic Design Theory for beginners', "Vectr: Beginner's Guide To Graphic Design", 'Graphic design: Designing 4 Advertisements in a series!', 'The Ultimate Canva Course For Beginners: Graphic Design']
#
# Graphic Design: Unity and Rhythm Master Class
# Top Similar Titles: ['Graphic Design', 'Graphic Design Resources', 'Fundamentals of Graphic Design', 'Graphic Design Theory for beginners', 'Graphic Design Basics for Educators Using Free Software']
#
# Graphic Elements of Design: Color Theory and Image Formats
# Top Similar Titles: ['Graphic Design Theory for beginners', 'Fundamentals of Graphic Design', 'Graphic Design', 'Ideas from the History of Graphic Design', "Vectr: Beginner's Guide To Graphic Design"]
#
# Hollywood: History,Industry, Art
# Top Similar Titles: ['The Craft of Storytelling', 'Graphic Design', 'Graphic Design Career Opportunity', 'Graphic Design Resources', 'Storytelling for SocialChange']
#
# How to Ideate: Creative Strategy/Brief
# Top Similar Titles: ['Creative Brief', 'Creativity and Creative Block', 'Academic English: How toWrite an Essay', "Graphic Design for Entrepreneurs...Who Can't Draw", 'Creating Integrated Marketing Plan']
#
# Hypothesis Testing
# Top Similar Titles: ['Hypothetical Testing and AB Test', 'Regression and Inferential Analysis', 'Correlation Analysis', 'Correlation Analysis', 'Marketing Analytics: Experiment & Evaluation']
#
# Hypothetical Testing and AB Test
# Top Similar Titles: ['Hypothesis Testing', 'IELTS Academic TestPreparation', 'Understanding the TOEFLEssentials Test', 'TOEFL® Test Preparation:The Insider’s Guide', 'Regression and Inferential Analysis']
#
# Ideas from the History of Graphic Design
# Top Similar Titles: ['Graphic Design Theory for beginners', 'Graphic Design', 'Fundamentals of Graphic Design', 'Introduction To Graphic Design', 'Introduction to Graphic Design']
#
# IELTS Academic TestPreparation
# Top Similar Titles: ['Understanding the TOEFLEssentials Test', 'Academic English: How toWrite an Essay', 'Academic and BusinessWriting', 'Business WritingTechniques', 'Digital Marketing Essentials Masterclass']
#
# Inclusive Growth: ClimateChange
# Top Similar Titles: ['Macroeconomics ofClimate Change: Science,Economics, and Policies', 'Macroeconomics ofClimate Change: ClimateRisks for the Financial Se…', 'Macroeconomics ofClimate Change: GreenPublic Finance', 'Climate Change: FinancialRisks and Opportunities', 'Macroeconomics ofClimate Change:Economics of Adaptation']
#
# Indexing, Slicing, Filtering, and Shorting
# Top Similar Titles: ['Cohort and Retention Analysis', 'Cohort and Retention Analysis Practice', 'Subquery and Common Table Expression', 'Table Creating and Manipulation', 'Table Reshaping']
#
# Información financiera ysu análisis
# Top Similar Titles: ['Financial Market Analysis', 'Dasar-Dasar Keuangan', 'Data Analysis Fundamental', 'Revenue Forecasting andAnalysis', 'ChatGPT for Data Analysis']
#
# Inglés para todos: nivelbásico
# Top Similar Titles: ['Inglés para todos: nivelbásico más', 'English for Journalists,Part 1', 'Basic Spanish 1: GettingStarted', 'Basic Spanish 2: One StepFurther', 'Basic SQL']
#
# Inglés para todos: nivelbásico más
# Top Similar Titles: ['Inglés para todos: nivelbásico', 'English for Journalists,Part 1', 'Basic Spanish 2: One StepFurther', 'Mandarin Chinese Level 1', 'Basic Spanish 1: GettingStarted']
#
# Innovation Through Design: Think, Make, Break, Repeat
# Top Similar Titles: ['Graphic design: top 6 fundamental rules to master design', 'Design Styles', 'Ideas from the History of Graphic Design', 'Graphic Design: Unity and Rhythm Master Class', 'The Ultimate Canva Course For Beginners: Graphic Design']
#
# Inspiration: Success & Award Winning Campaigns
# Top Similar Titles: ['Creating Campaign Planning', 'Campaign & Media Planning', 'Campaign Fundamentals', 'Brand Campaign Touchpoints', 'Brand & Creative Strategy']
#
# Intellectual Property, Copyright, License
# Top Similar Titles: ['Logo Design', 'Branding Introduction', 'Paid Content Marketing', 'Designing Brand Identity', 'Introduction to Typography']
#
# Interactive Computer Graphics
# Top Similar Titles: ['Graphic Design', 'Introduction to Graphic Design', 'Introduction To Graphic Design', 'Graphic Design Resources', 'Fundamentals of Graphic Design']
#
# InterculturalCommunication at Work –Land the job and do it well
# Top Similar Titles: ['Storytelling in theWorkplace', 'Soft Skills: CollaborateEffectively', 'Comunicación yRedacción Digital', 'Teamwork & Collaboration', 'Using Email forNetworking in English']
#
# Interest Rate RiskManagement in Banks/Financial Institution
# Top Similar Titles: ['VITARA - Compliance RiskManagement', 'Macroeconomics ofClimate Change: ClimateRisks for the Financial Se…', 'Introducción a lasfinanzas: Principios devaloración', 'Introduction to PersonalFinancial Planning', 'Climate Change: FinancialRisks and Opportunities']
#
# Intro to Pandas
# Top Similar Titles: ['Master Data Analysis with Python - Intro to Pandas', 'Pandas Datetime', 'Basics of Pandas for Data Analysis & Data Science', 'Intro to Stock Trading', 'All About Dictionary Python']
#
# Intro to Stock Trading
# Top Similar Titles: ['Introducción a la inversiónbursátil', 'Introduction to FinTech', 'Introduction to PersonalFinancial Planning', 'Intro to Pandas', 'Introduction toMathematics for Financeand Business']
#
# Introducción a la inversiónbursátil
# Top Similar Titles: ['Intro to Stock Trading', 'Introduction to FinTech', 'Introduction to PersonalFinancial Planning', 'Marketing Introduction', 'Introduction to Statistics']
#
# Introducción a lasfinanzas: Principios devaloración
# Top Similar Titles: ['Introduction to FinTech', 'Introduction to PersonalFinancial Planning', 'Introduction toMathematics for Financeand Business', 'Pengantar Analisis Merek Digital untuk Pemula', 'Introducción a la inversiónbursátil']
#
# Introducción al griegoclásico: lengua, nombres ymitología
# Top Similar Titles: ['Italian Language andCulture: Advanced(2023-2024)', 'Introducción a la inversiónbursátil', 'Italian Language andCulture: Beginner(2023-2024)', 'Introduction toMathematics for Financeand Business', 'Introduction to Typography']
#
# Introduction and Installation
# ...
#
# Population Health: Responsible Data Analysis
# Top Similar Titles: ['Data Analysis Fundamental', 'ChatGPT for Data Analysis', 'Clustering Analysis', 'Financial Market Analysis', 'Basics of Plotly for Data Analysis & Data Science']
#
# Power BI: Dasbor untuk Pemula
# Top Similar Titles: ['Pelatihan Esensial Power BI', 'From Excel to Power BI', 'Data Analysis with Excel and Power BI', 'Finding the Brand Benefit', "Graphic Design for Entrepreneurs...Who Can't Draw"]
#
# Preparing Your Career as Campaign Planner
# Top Similar Titles: ['Creating Campaign Planning', 'Campaign & Media Planning', 'Funnelling & Media Planning', 'Strategi Memulai Digital Marketing dari Awal', 'Introduction to PersonalFinancial Planning']
#
# Probability and Distribution
# Top Similar Titles: ['Statistics', 'Statistics Introduction', 'Revenue Forecasting andAnalysis', 'Statistics and data literacy for non-statisticians', 'MacroeconometricForecasting']
#
# Process Mining: Data Science in Action
# Top Similar Titles: ['Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Dasar-Dasar Ilmu Data: Penggalian Data', 'Data Science Projects - Data Analysis & Machine Learning', 'Data Science, Machine Learning, Data Analysis, Python & R']
#
# Professional Advertising & Graphic Design [Mascot/Logo]
# Top Similar Titles: ['Canva Pro Graphic Design Course for Business Professionals', 'Graphic Design Career Opportunity', 'Graphic Design', 'Graphic design: Designing 4 Advertisements in a series!', 'Graphic Design Resources']
#
# Professional BusinessPresentations
# Top Similar Titles: ['Business Communication', 'Business Metrics', 'Professional Advertising & Graphic Design [Mascot/Logo]', 'Canva Pro Graphic Design Course for Business Professionals', 'Business WritingTechniques']
#
# Project: Clustering Model
# Top Similar Titles: ['Project: Prediction Model', 'Clustering Analysis', 'Feature Engineering', 'Data Science Projects - Data Analysis & Machine Learning', 'Kepemimpinan Proyek']
#
# Project: Prediction Model
# Top Similar Titles: ['Project: Clustering Model', 'MacroeconometricForecasting', 'Kepemimpinan Proyek', 'Hypothesis Testing', 'Fundamentals Data Analysis & Decision Making Models - Theory']
#
# Public Speaking
# Top Similar Titles: ['Professional BusinessPresentations', 'Consumer & Audience Insight', 'Becoming an EffectiveLeader', 'Business Communication', 'Marketing Introduction']
#
# Python 101 - For Data Analysis
# Top Similar Titles: ['Python for Data Analysis', 'Python and Statistics for Financial Analysis', 'Basics of Numpy for Data Analysis & Data Science', 'Data Science, Machine Learning, Data Analysis, Python & R', 'Basics of Matplotlib for Data Analysis & Data Science']
#
# Python and Statistics for Financial Analysis
# Top Similar Titles: ['Python for Data Analysis', 'Python 101 - For Data Analysis', 'Master Data Analysis with Python - Intro to Pandas', 'Basics of Matplotlib for Data Analysis & Data Science', 'Basics of Numpy for Data Analysis & Data Science']
#
# Python for Data Analysis
# Top Similar Titles: ['Python 101 - For Data Analysis', 'Basics of Numpy for Data Analysis & Data Science', 'Python and Statistics for Financial Analysis', 'Basics of Matplotlib for Data Analysis & Data Science', 'Data Structure in Python']
#
# Regression and Inferential Analysis
# Top Similar Titles: ['Revenue Forecasting andAnalysis', 'Correlation Analysis', 'Correlation Analysis', 'Clustering Analysis', 'Visualisasi Data untuk Analisis dan Analitik Data']
#
# Regular Advance Expression
# Top Similar Titles: ['Regular Expression Python', 'Subquery and Common Table Expression', 'Line, Shape, and Form', 'Digital Platforms inPerformance', 'Leading With EffectiveCommunication (InclusiveLeadership Training)']
#
# Regular Expression Python
# Top Similar Titles: ['String in Python', 'Function in Python', 'All About Dictionary Python', 'Data Structure in Python', 'List Fundamental in Python']
#
# Relationship and Alter Table
# Top Similar Titles: ['Table Creating and Manipulation', 'Table Reshaping', 'Subquery and Common Table Expression', 'SQL String and Date Function', 'Pelatihan Penting Tableau']
#
# Revenue Forecasting andAnalysis
# Top Similar Titles: ['Regression and Inferential Analysis', 'Monetary Policy Analysisand Forecasting', 'MacroeconometricForecasting', 'Información financiera ysu análisis', 'Financial Market Analysis']
#
# Search, Match and Find All
# Top Similar Titles: ['Metodologi Penelitian untuk Pemula', 'Finding the Brand Benefit', 'Market Research & Objective', 'Fundamentals of Color and Appearance', 'Regular Expression Python']
#
# Skills and Tools in Data Analysis
# Top Similar Titles: ['Visualisasi Data untuk Analisis dan Analitik Data', 'Belajar Excel: Analisis Data', 'ChatGPT for Data Analysis', 'Data Science Projects - Data Analysis & Machine Learning', 'Basics of Plotly for Data Analysis & Data Science']
#
# Social Media Marketing untuk Pemula
# Top Similar Titles: ['Dasar-Dasar Pemasaran Media Sosial', 'Basic Digital Marketing untuk Pemula', 'Digital Marketing for Beginners 2023', 'Kursus Digital Marketing untuk Pemula', 'Digital Marketing Course for Beginners']
#
# Soft Skills: CollaborateEffectively
# Top Similar Titles: ['Soft Skills: DevelopInterpersonal Skills', 'Teamwork & Collaboration', 'Becoming an EffectiveLeader', 'Comunicación efectivapara el líder actual', 'Business WritingTechniques']
#
# Soft Skills: DevelopInterpersonal Skills
# Top Similar Titles: ['Soft Skills: CollaborateEffectively', 'Skills and Tools in Data Analysis', 'Leaders of Learning', 'Becoming an EffectiveLeader', 'Dasar-Dasar Pemasaran Digital']
#
# SQL Advance: Group By & Agregat
# Top Similar Titles: ['SQL Joins', 'SQL Keyword', 'Basic SQL', 'SQL String and Date Function', 'Subquery and Common Table Expression']
#
# SQL for Data Analysis: Solving real-world problems with data
# Top Similar Titles: ['Basics of Plotly for Data Analysis & Data Science', 'ChatGPT for Data Analysis', 'Pengantar Analisis Data untuk Memecahkan Masalah Kualitas', 'Python for Data Analysis', 'Basics of Seaborn for Data Analysis & Data Science']
#
# SQL Joins
# Top Similar Titles: ['SQL Keyword', 'Basic SQL', 'SQL Advance: Group By & Agregat', 'SQL String and Date Function', 'Case Study: Implementing SQL']
#
# SQL Keyword
# Top Similar Titles: ['Basic SQL', 'SQL Joins', 'SQL String and Date Function', 'SQL Advance: Group By & Agregat', 'Case Study: Implementing SQL']
#
# SQL Mastery & Data Analysis - A Teaser
# Top Similar Titles: ['SQL for Data Analysis: Solving real-world problems with data', 'Visualisasi Data untuk Analisis dan Analitik Data', 'Basics of Plotly for Data Analysis & Data Science', 'ChatGPT for Data Analysis', 'Belajar Excel: Analisis Data']
#
# SQL String and Date Function
# Top Similar Titles: ['SQL Keyword', 'SQL Joins', 'Basic SQL', 'Datetime', 'SQL Advance: Group By & Agregat']
#
# Stand Up!; ComedyWriting and PerformancePoetry
# Top Similar Titles: ['Relationship and Alter Table', 'Table Creating and Manipulation', 'Cohort and Retention Analysis', 'Academic and BusinessWriting', 'Comunicación yRedacción Digital']
#
# Statistics
# Top Similar Titles: ['Statistics Introduction', 'Introduction to Statistics', 'Correlation Analysis', 'Correlation Analysis', 'Statistics and data literacy for non-statisticians']
#
# Statistics and data literacy for non-statisticians
# Top Similar Titles: ['Statistics', 'Introduction to Statistics', 'Statistics Introduction', 'Python and Statistics for Financial Analysis', 'Skills and Tools in Data Analysis']
#
# Statistics Introduction
# Top Similar Titles: ['Introduction to Statistics', 'Statistics', 'Data Science Introduction', 'Marketing Introduction', 'Database Introduction']
#
# Steps in Japanese forBeginners1 Part1
# Top Similar Titles: ['Mandarin ChineseEssentials', 'Mandarin Chinese forBusiness', 'Mandarin Chinese Level 1', 'Italian Language andCulture: Intermediate(2023-2024)', 'Italian Language andCulture: Advanced(2023-2024)']
#
# Stored Procedure
# Top Similar Titles: ['SQL Joins', 'SQL Keyword', 'Basic SQL', 'SQL String and Date Function', 'Case Study: Implementing SQL']
#
# Storytelling for SocialChange
# Top Similar Titles: ['Storytelling in theWorkplace', 'The Craft of Storytelling', 'Social Media Marketing untuk Pemula', 'Dasar-Dasar Pemasaran Media Sosial', 'Marketing Introduction']
#
# Storytelling in theWorkplace
# Top Similar Titles: ['Storytelling for SocialChange', 'The Craft of Storytelling', 'Business WritingTechniques', 'Teamwork & Collaboration', 'InterculturalCommunication at Work –Land the job and do it well']
#
# Strategi Memulai Digital Marketing dari Awal
# Top Similar Titles: ['Digital Marketing Course | Digital Marketing Tutorial', 'Digital Marketing for Beginners 2023', 'Marketing for Entrepreneurs in 2022: Learn Digital Marketing', 'Digital Marketing Strategy for Managers', 'Basic Digital Marketing untuk Pemula']
#
# String in Python
# Top Similar Titles: ['Function in Python', 'Regular Expression Python', 'List Fundamental in Python', 'Data Structure in Python', 'All About Dictionary Python']
#
# Study Case : Finance
# Top Similar Titles: ['Foundations of Finance', 'Financial Market Analysis', 'Información financiera ysu análisis', 'Dasar-Dasar Keuangan', 'Case Study: Implementing SQL']
#
# Subquery and Common Table Expression
# Top Similar Titles: ['SQL Joins', 'Relationship and Alter Table', 'SQL Advance: Group By & Agregat', 'SQL String and Date Function', 'SQL Keyword']
#
# Table Creating and Manipulation
# Top Similar Titles: ['Relationship and Alter Table', 'Table Reshaping', 'Creating Campaign Planning', 'Pelatihan Penting Tableau', 'Subquery and Common Table Expression']
#
# Table Reshaping
# Top Similar Titles: ['Relationship and Alter Table', 'Table Creating and Manipulation', 'Pelatihan Penting Tableau', 'Data Visualization Seaborn', 'Database Introduction']
#
# Target Market Mapping
# Top Similar Titles: ['Market Research & Objective', 'Creating Integrated Marketing Plan', 'Financial Market Analysis', 'Marketing Business Metrics', 'Assessing Marketing Materials']
#
# Teamwork & Collaboration
# Top Similar Titles: ['Soft Skills: CollaborateEffectively', 'Storytelling in theWorkplace', 'Leading High-PerformingTeams', 'Kepemimpinan Proyek', 'Business Communication']
#
# Text Analysis
# Top Similar Titles: ['Descriptive Analysis', 'Data Analysis Fundamental', 'ChatGPT for Data Analysis', 'Clustering Analysis', 'Correlation Analysis']
#
# The A-Z Digital Marketing Course - Everything Under 30min!
# Top Similar Titles: ['Digital Marketing Essentials Masterclass', 'Digital Marketing Course | Digital Marketing Tutorial', 'Digital Marketing FAQs - Common Digital Marketing Questions', 'Digital Marketing Course for Beginners', 'Digital Marketing Masterclass in 2 Hours']
#
# The Craft of Storytelling
# Top Similar Titles: ['Storytelling in theWorkplace', 'Storytelling for SocialChange', 'The Strategy of Content Marketing', 'Business WritingTechniques', 'Funnelling & Media Planning']
#
# The Language of Design: Form and Meaning
# Top Similar Titles: ['Design Terminology', 'El cerebro y las emocionesen el lenguaje', 'Line, Shape, and Form', 'Merancang dan Mengkreasikan Iklan Dengan Semiotika Visual', 'Design Styles']
#
# The Strategy of Content Marketing
# Top Similar Titles: ['Content Marketing', 'Paid Content Marketing', 'Digital Marketing Strategy for Managers', 'Pemasaran Media Sosial: Strategi dan Pengoptimalan', 'Dasar-Dasar Pemasaran Media Sosial']
#
# The Ultimate Canva Course For Beginners: Graphic Design
# Top Similar Titles: ['Graphic Design Theory for beginners', "Vectr: Beginner's Guide To Graphic Design", 'Amazing Graphic Design for Beginners in 3 EASY STEPS', 'Learn Canva & Canva Pro - Easiest Graphic Design Course 2023', 'Beginners Guide To Graphic Design Without Paid Software']
#
# Tips dan Trik Visualisasi Data
# Top Similar Titles: ['Data Visualization Plotly', 'Data Visualization Practice', 'Basic of Data Visualization', 'Data Visualization', 'Data Visualization Seaborn']
#
# TOEFL® Test Preparation:The Insider’s Guide
# Top Similar Titles: ['Understanding the TOEFLEssentials Test', 'IELTS Academic TestPreparation', "Vectr: Beginner's Guide To Graphic Design", 'Hypothetical Testing and AB Test', 'Study Case : Finance']
#
# Transaction Classification of Fraud and Non Fraud
# Top Similar Titles: ['Table Creating and Manipulation', 'Relationship and Alter Table', 'Statistics and data literacy for non-statisticians', 'Fundamentos deinformación financiera ycontable', 'Academic and BusinessWriting']
#
# Typography
# Top Similar Titles: ['Introduction to Typography', 'Graphic Design', 'Logo Design', 'Graphic Design Resources', 'Design Styles']
#
# UCI Data Preprocessing and Exploratory Data Analysis
# Top Similar Titles: ['Visualisasi Data untuk Analisis dan Analitik Data', 'ChatGPT for Data Analysis', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Data Science Projects - Data Analysis & Machine Learning']
#
# Understanding Clinical Research: Behind the Statistics
# Top Similar Titles: ['Python and Statistics for Financial Analysis', 'Statistics', 'Population Health: Responsible Data Analysis', 'Introduction to Statistics', 'Analisis Bisnis untuk Pemula : Metode Statistik']
#
# Understanding the TOEFLEssentials Test
# Top Similar Titles: ['IELTS Academic TestPreparation', 'TOEFL® Test Preparation:The Insider’s Guide', 'Digital Marketing Essentials Masterclass', 'Academic English: How toWrite an Essay', 'Introduction to FinTech']
#
# Unlocking Investment andFinance in EmergingMarkets and Developing…
# Top Similar Titles: ['Finanzas e inversionespara no financieros', 'Financial accounting andcapital markets', 'Fundamentos deinformación financiera ycontable', 'Financial Development andFinancial Inclusion', 'Financial Market Analysis']
#
# Upper-IntermediateEnglish: Business andGlobalization
# Top Similar Titles: ['Upper-IntermediateEnglish: Business andIndustry', 'Upper-IntermediateEnglish: Business andTechnology', 'Academic and BusinessWriting', 'Italian Language andCulture: Beginner(2023-2024)', 'Italian Language andCulture: Intermediate(2023-2024)']
#
# Upper-IntermediateEnglish: Business andIndustry
# Top Similar Titles: ['Upper-IntermediateEnglish: Business andTechnology', 'Upper-IntermediateEnglish: Business andGlobalization', 'Academic and BusinessWriting', 'Business WritingTechniques', 'Introduction toMathematics for Financeand Business']
#
# Upper-IntermediateEnglish: Business andTechnology
# Top Similar Titles: ['Upper-IntermediateEnglish: Business andIndustry', 'Upper-IntermediateEnglish: Business andGlobalization', 'Business WritingTechniques', 'Academic and BusinessWriting', 'Introduction toMathematics for Financeand Business']
#
# Using Email forNetworking in English
# Top Similar Titles: ['Academic English: How toWrite an Essay', 'English for Journalists,Part 1', 'Leer y escribir en launiversidad', 'Email marketing: diseño ygestión de campañas', 'Upper-IntermediateEnglish: Business andGlobalization']
#
# Vectr: Beginner's Guide To Graphic Design
# Top Similar Titles: ['Graphic Design Theory for beginners', 'Beginners Guide To Graphic Design Without Paid Software', 'The Ultimate Canva Course For Beginners: Graphic Design', 'Introduction To Graphic Design', 'Introduction to Graphic Design']
#
# Visualisasi Data untuk Analisis dan Analitik Data
# Top Similar Titles: ['ChatGPT for Data Analysis', 'UCI Data Preprocessing and Exploratory Data Analysis', 'Basics of Plotly for Data Analysis & Data Science', 'Basics of Seaborn for Data Analysis & Data Science', 'Data Visualization Plotly']
#
# VITARA - Compliance RiskManagement
# Top Similar Titles: ['Interest Rate RiskManagement in Banks/Financial Institution', 'Digital Marketing Strategy for Managers', 'Climate Change: FinancialRisks and Opportunities', 'KOL Management untuk Sosial Media Marketing', 'MacroeconometricForecasting']
#
# Writing Feature Articles
# Top Similar Titles: ['Business WritingTechniques', 'Text Analysis', 'Creative Brief', 'Academic and BusinessWriting', 'Comunicación yRedacción Digital']
